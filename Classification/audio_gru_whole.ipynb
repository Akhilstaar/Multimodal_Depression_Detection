# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F
import torch.optim as optim
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

import numpy as np
import pandas as pd
import os
import pickle
import random
import itertools

# %%
config = {
    'num_classes': 2,
    'dropout': 0.5,
    'rnn_layers': 2,
    'embedding_size': 256,
    'batch_size': 8,
    'epochs': 170,
    'learning_rate': 6e-6,
    'hidden_dims': 256,
    'bidirectional': False,
    'cuda': False
}

prefix = os.path.abspath(os.path.join(os.getcwd(), ".."))
audio_features = np.squeeze(np.load(os.path.join(prefix, 'Features/AudioWhole/whole_samples_clf_256.npz'))['arr_0'], axis=2)
audio_targets = np.load(os.path.join(prefix, 'Features/AudioWhole/whole_labels_clf_256.npz'))['arr_0']
audio_dep_idxs_tmp = np.where(audio_targets == 1)[0]
audio_non_idxs = np.where(audio_targets == 0)[0]

# %%
class AudioBiLSTM(nn.Module):
    def __init__(self, config):
        super(AudioBiLSTM, self).__init__()
        self.num_classes = config['num_classes']
        self.learning_rate = config['learning_rate']
        self.dropout = config['dropout']
        self.hidden_dims = config['hidden_dims']
        self.rnn_layers = config['rnn_layers']
        self.embedding_size = config['embedding_size']
        self.bidirectional = config['bidirectional']

        self.build_model()

    def init_weight(net):
        for name, param in net.named_parameters():
            if not 'ln' in name:
                if 'bias' in name:
                    nn.init.constant_(param, 0.0)
                elif 'weight' in name:
                    nn.init.xavier_uniform_(param)

    def build_model(self):
        # attention layer
        self.attention_layer = nn.Sequential(
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(inplace=True))

        self.lstm_net_audio = nn.GRU(self.embedding_size, self.hidden_dims,
                                num_layers=self.rnn_layers, dropout=self.dropout, batch_first=True)

        self.ln = nn.LayerNorm(self.embedding_size)

        # FC
        self.fc_audio = nn.Sequential(
            nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(),
            nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.num_classes),
            nn.Softmax(dim=1)
        )

    def attention_net_with_w(self, lstm_out, lstm_hidden):
        '''
        :param lstm_out:    [batch_size, len_seq, n_hidden * 2]
        :param lstm_hidden: [batch_size, num_layers * num_directions, n_hidden]
        :return: [batch_size, n_hidden]
        '''
        lstm_tmp_out = torch.chunk(lstm_out, 2, -1)
        # h [batch_size, time_step, hidden_dims]
        h = lstm_tmp_out[0] + lstm_tmp_out[1]
        # h = lstm_out
        # [batch_size, num_layers * num_directions, n_hidden]
        lstm_hidden = torch.sum(lstm_hidden, dim=1)
        # [batch_size, 1, n_hidden]
        lstm_hidden = lstm_hidden.unsqueeze(1)
        # atten_w [batch_size, 1, hidden_dims]
        atten_w = self.attention_layer(lstm_hidden)
        # m [batch_size, time_step, hidden_dims]
        m = nn.Tanh()(h)
        # atten_context [batch_size, 1, time_step]
       # print(atten_w.shape, m.transpose(1, 2).shape)
        atten_context = torch.bmm(atten_w, m.transpose(1, 2))
        # softmax_w [batch_size, 1, time_step]
        softmax_w = F.softmax(atten_context, dim=-1)
        # context [batch_size, 1, hidden_dims]
        context = torch.bmm(softmax_w, h)
        result = context.squeeze(1)
        return result

    def forward(self, x):
        x = self.ln(x)
        x, _ = self.lstm_net_audio(x)
        x = x.mean(dim=1)
        out = self.fc_audio(x)
        return out

# %%
def save(model, filename):
    save_filename = '{}.pt'.format(filename)
    torch.save(model, save_filename)
    print('Saved as %s' % save_filename)

# %%
def standard_confusion_matrix(y_test, y_test_pred):
    """
    Make confusion matrix with format:
                  -----------
                  | TP | FP |
                  -----------
                  | FN | TN |
                  -----------
    Parameters
    ----------
    y_true : ndarray - 1D
    y_pred : ndarray - 1D

    Returns
    -------
    ndarray - 2D
    """
    [[tn, fp], [fn, tp]] = confusion_matrix(y_test.cpu().numpy(), y_test_pred)
    return np.array([[tp, fp], [fn, tn]])

def model_performance(y_test, y_test_pred_proba):
    """
    Evaluation metrics for network performance.
    """
    y_test_pred = y_test_pred_proba.data.max(1, keepdim=True)[1]

    # Computing confusion matrix for test dataset
    conf_matrix = standard_confusion_matrix(y_test, y_test_pred.numpy())
    print("Confusion Matrix:")
    print(conf_matrix)

    return y_test_pred, conf_matrix

def train(epoch, train_idxs):
    global lr, train_acc
    model.train()
    batch_idx = 1      
    total_loss = 0
    correct = 0
    pred = np.array([])
    X_train = audio_features[train_idxs]
    Y_train = audio_targets[train_idxs]
    for i in range(0, X_train.shape[0], config['batch_size']):
        if i + config['batch_size'] > X_train.shape[0]:
            x, y = X_train[i:], Y_train[i:]
        else:
            x, y = X_train[i:(i + config['batch_size'])], Y_train[i:(
                i + config['batch_size'])]
        if config['cuda']:
            x, y = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad=True).cuda(), Variable(torch.from_numpy(y)).cuda()
        else:
            x, y = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad=True), \
                Variable(torch.from_numpy(y))

        optimizer.zero_grad()
        output = model(x)
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(y.data.view_as(pred)).cpu().sum()
        y = y.long()
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        batch_idx += 1
        total_loss += loss.item()

    train_acc = correct
    print(
        'Train Epoch: {:2d}\t Learning rate: {:.4f}\tLoss: {:.6f}\t Accuracy: {}/{} ({:.0f}%)\n '
        .format(epoch + 1, config['learning_rate'], total_loss, correct,
                X_train.shape[0], 100. * correct / X_train.shape[0]))

# %%
def evaluate(model, test_idxs, fold, train_idxs_tmp, train_idxs):
    model.eval()
    batch_idx = 1
    total_loss = 0
    global max_f1, max_acc, min_mae, X_test_lens, max_prec, max_rec
    pred = np.array([])
    with torch.no_grad():
        if config['cuda']:
            x, y = Variable(torch.from_numpy(audio_features[test_idxs]).type(torch.FloatTensor), requires_grad=True).cuda(),\
                Variable(torch.from_numpy(audio_targets[test_idxs])).cuda()
        else:
            x, y = Variable(torch.from_numpy(audio_features[test_idxs]).type(torch.FloatTensor), requires_grad=True), \
                Variable(torch.from_numpy(audio_targets[test_idxs])).type(torch.LongTensor)

        optimizer.zero_grad()
        output = model(x)
        loss = criterion(output, y)
        total_loss += loss.item()
        y_test_pred, conf_matrix = model_performance(y, output.cpu())
        accuracy = float(conf_matrix[0][0] + conf_matrix[1][1]) / np.sum(conf_matrix)
        precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
        recall = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[1][0])
        f1_score = 2 * (precision * recall) / (precision + recall)
        print("Accuracy: {}".format(accuracy))
        print("Precision: {}".format(precision))
        print("Recall: {}".format(recall))
        print("F1-Score: {}\n".format(f1_score))
        print('=' * 89)

        if max_f1 <= f1_score and train_acc > len(train_idxs)*0.90  and f1_score > 0.5:
            max_f1 = f1_score
            max_acc = accuracy
            max_rec = recall
            max_prec = precision
            mode ='gru'
            save(model, os.path.join(prefix, 'Model/ClassificationWhole/Audio/BiLSTM_{}_vlad{}_{}_{:.2f}_{}'.format(mode, config['embedding_size'], config['hidden_dims'], max_f1, fold)))
            np.save(os.path.join(prefix, 'Features/TextWhole/train_idxs_{:.2f}_{}.npy'.format(f1_score, fold)), train_idxs_tmp)
            print('*' * 64)
            print('model saved: f1: {}\tacc: {}'.format(max_f1, max_acc))
            print('*' * 64)

    return total_loss

def get_param_group(model):
    nd_list = []
    param_list = []
    for name, param in model.named_parameters():
        if 'ln' in name:
            nd_list.append(param)
        else:
            param_list.append(param)
    return [{'params': param_list, 'weight_decay': 1e-5}, {'params': nd_list, 'weight_decay': 0}]

# %%
## Run this if the random indices do not give trainable model for fusenet.

# prefix = os.path.abspath(os.path.join(os.getcwd(), ".."))
# text_features = np.load(os.path.join(prefix, 'Features/TextWhole/whole_samples_clf_avg.npz'))['arr_0']
# text_targets = np.load(os.path.join(prefix, 'Features/TextWhole/whole_labels_clf_avg.npz'))['arr_0']
# text_dep_idxs_tmp = np.where(text_targets == 1)[0]
# text_non_idxs = np.where(text_targets == 0)[0]

# kf = KFold(n_splits=3, shuffle=True)
# fold = 1
# for train_idxs_tmp, test_idxs_tmp in kf.split(text_features):
#     ## Code to save the .npy files.
#     np.save(os.path.join(prefix, 'Features/TextWhole/train_idxs_{}.npy'.format(fold)), train_idxs_tmp)
#     np.save(os.path.join(prefix, 'Features/TextWhole/test_idxs_{}.npy'.format(fold)), test_idxs_tmp)
#     fold += 1

# %%
train_idxs_tmps = [np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_1.npy'), allow_pickle=True),
np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_2.npy'), allow_pickle=True),
np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_3.npy'), allow_pickle=True)]

# %%
for idx_idx, train_idxs_tmp in enumerate(train_idxs_tmps):
    fold = idx_idx + 1
    test_idxs_tmp = list(set(list(audio_dep_idxs_tmp)+list(audio_non_idxs)) - set(train_idxs_tmp))
    train_idxs, test_idxs = [], []
    resample_idxs = [0,1,2,3,4,5]
    
    # depression data augmentation
    for idx in train_idxs_tmp:
        if idx in audio_dep_idxs_tmp:
            feat = audio_features[idx]
            count = 0
            for i in itertools.permutations(feat, feat.shape[0]):
                if count in resample_idxs:
                    audio_features = np.vstack((audio_features, np.expand_dims(list(i), 0)))
                    audio_targets = np.hstack((audio_targets, 1))
                    train_idxs.append(len(audio_features)-1)
                count += 1
        else:
            train_idxs.append(idx)

    for idx in test_idxs_tmp:
        if idx in audio_dep_idxs_tmp:
            feat = audio_features[idx]
            count = 0
            # resample_idxs = random.sample(range(6), 4)
            resample_idxs = [0,1,4,5]
            for i in itertools.permutations(feat, feat.shape[0]):
                if count in resample_idxs:
                    audio_features = np.vstack((audio_features, np.expand_dims(list(i), 0)))
                    audio_targets = np.hstack((audio_targets, 1))
                    test_idxs.append(len(audio_features)-1)
                count += 1
        else:
            test_idxs.append(idx)

    model = AudioBiLSTM(config)

    if config['cuda']:
        model = model.cuda()

    param_group = get_param_group(model)
    optimizer = optim.AdamW(param_group, lr=config['learning_rate'])
    criterion = nn.CrossEntropyLoss()
    max_f1 = -1
    max_acc = -1
    max_rec = -1
    max_prec = -1
    train_acc = -1

    for ep in range(1, config['epochs']):
        train(ep, train_idxs)
        tloss = evaluate(model, test_idxs, fold, train_idxs_tmp, train_idxs)
    fold += 1
# Out:
# Train Epoch:  2	 Learning rate: 0.0000	Loss: 18.792506	 Accuracy: 92/213 (43%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch:  3	 Learning rate: 0.0000	Loss: 18.873885	 Accuracy: 88/213 (41%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch:  4	 Learning rate: 0.0000	Loss: 18.820585	 Accuracy: 91/213 (43%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch:  5	 Learning rate: 0.0000	Loss: 18.824470	 Accuracy: 93/213 (44%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch:  6	 Learning rate: 0.0000	Loss: 18.794869	 Accuracy: 90/213 (42%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch:  7	 Learning rate: 0.0000	Loss: 18.778364	 Accuracy: 101/213 (47%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch:  8	 Learning rate: 0.0000	Loss: 18.731972	 Accuracy: 96/213 (45%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch:  9	 Learning rate: 0.0000	Loss: 18.736921	 Accuracy: 98/213 (46%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch: 10	 Learning rate: 0.0000	Loss: 18.738316	 Accuracy: 107/213 (50%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch: 11	 Learning rate: 0.0000	Loss: 18.710631	 Accuracy: 109/213 (51%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch: 12	 Learning rate: 0.0000	Loss: 18.705779	 Accuracy: 105/213 (49%)
#
# Confusion Matrix:
# [[ 0  0]
#  [36 45]]
# Accuracy: 0.5555555555555556
# Precision: nan
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:21: RuntimeWarning: invalid value encountered in divide
#   precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
# Train Epoch: 13	 Learning rate: 0.0000	Loss: 18.714300	 Accuracy: 104/213 (49%)
#
# Confusion Matrix:
# [[ 0  1]
#  [36 44]]
# Accuracy: 0.5432098765432098
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 14	 Learning rate: 0.0000	Loss: 18.678832	 Accuracy: 114/213 (54%)
#
# Confusion Matrix:
# [[ 0  1]
#  [36 44]]
# Accuracy: 0.5432098765432098
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 15	 Learning rate: 0.0000	Loss: 18.699854	 Accuracy: 110/213 (52%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 16	 Learning rate: 0.0000	Loss: 18.680840	 Accuracy: 115/213 (54%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 17	 Learning rate: 0.0000	Loss: 18.671760	 Accuracy: 111/213 (52%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 18	 Learning rate: 0.0000	Loss: 18.674310	 Accuracy: 105/213 (49%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 19	 Learning rate: 0.0000	Loss: 18.697718	 Accuracy: 109/213 (51%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 20	 Learning rate: 0.0000	Loss: 18.645674	 Accuracy: 122/213 (57%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 21	 Learning rate: 0.0000	Loss: 18.667845	 Accuracy: 115/213 (54%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 22	 Learning rate: 0.0000	Loss: 18.603519	 Accuracy: 130/213 (61%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 23	 Learning rate: 0.0000	Loss: 18.650873	 Accuracy: 115/213 (54%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 24	 Learning rate: 0.0000	Loss: 18.603303	 Accuracy: 124/213 (58%)
#
# Confusion Matrix:
# [[ 0  2]
#  [36 43]]
# Accuracy: 0.5308641975308642
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 25	 Learning rate: 0.0000	Loss: 18.638351	 Accuracy: 117/213 (55%)
#
# Confusion Matrix:
# [[ 0  4]
#  [36 41]]
# Accuracy: 0.5061728395061729
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 26	 Learning rate: 0.0000	Loss: 18.619812	 Accuracy: 128/213 (60%)
#
# Confusion Matrix:
# [[ 0  4]
#  [36 41]]
# Accuracy: 0.5061728395061729
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 27	 Learning rate: 0.0000	Loss: 18.596916	 Accuracy: 131/213 (62%)
#
# Confusion Matrix:
# [[ 0  4]
#  [36 41]]
# Accuracy: 0.5061728395061729
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 28	 Learning rate: 0.0000	Loss: 18.568554	 Accuracy: 129/213 (61%)
#
# Confusion Matrix:
# [[ 0  4]
#  [36 41]]
# Accuracy: 0.5061728395061729
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 29	 Learning rate: 0.0000	Loss: 18.596994	 Accuracy: 123/213 (58%)
#
# Confusion Matrix:
# [[ 0  5]
#  [36 40]]
# Accuracy: 0.49382716049382713
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 30	 Learning rate: 0.0000	Loss: 18.591102	 Accuracy: 136/213 (64%)
#
# Confusion Matrix:
# [[ 0  5]
#  [36 40]]
# Accuracy: 0.49382716049382713
# Precision: 0.0
# Recall: 0.0
# F1-Score: nan
#
# =========================================================================================
# C:\Users\meena\AppData\Local\Temp\ipykernel_18544\520582756.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   f1_score = 2 * (precision * recall) / (precision + recall)
# Train Epoch: 31	 Learning rate: 0.0000	Loss: 18.546658	 Accuracy: 140/213 (66%)
#
# Confusion Matrix:
# [[ 1  7]
#  [35 38]]
# Accuracy: 0.48148148148148145
# Precision: 0.125
# Recall: 0.027777777777777776
# F1-Score: 0.04545454545454545
#
# =========================================================================================
# Train Epoch: 32	 Learning rate: 0.0000	Loss: 18.529120	 Accuracy: 148/213 (69%)
#
# Confusion Matrix:
# [[ 1  7]
#  [35 38]]
# Accuracy: 0.48148148148148145
# Precision: 0.125
# Recall: 0.027777777777777776
# F1-Score: 0.04545454545454545
#
# =========================================================================================
# Train Epoch: 33	 Learning rate: 0.0000	Loss: 18.532070	 Accuracy: 139/213 (65%)
#
# Confusion Matrix:
# [[ 2  9]
#  [34 36]]
# Accuracy: 0.4691358024691358
# Precision: 0.18181818181818182
# Recall: 0.05555555555555555
# F1-Score: 0.0851063829787234
#
# =========================================================================================
# Train Epoch: 34	 Learning rate: 0.0000	Loss: 18.495632	 Accuracy: 146/213 (69%)
#
# Confusion Matrix:
# [[ 2 10]
#  [34 35]]
# Accuracy: 0.4567901234567901
# Precision: 0.16666666666666666
# Recall: 0.05555555555555555
# F1-Score: 0.08333333333333333
#
# =========================================================================================
# Train Epoch: 35	 Learning rate: 0.0000	Loss: 18.509078	 Accuracy: 143/213 (67%)
#
# Confusion Matrix:
# [[ 4 11]
#  [32 34]]
# Accuracy: 0.4691358024691358
# Precision: 0.26666666666666666
# Recall: 0.1111111111111111
# F1-Score: 0.1568627450980392
#
# =========================================================================================
# Train Epoch: 36	 Learning rate: 0.0000	Loss: 18.491805	 Accuracy: 145/213 (68%)
#
# Confusion Matrix:
# [[ 4 14]
#  [32 31]]
# Accuracy: 0.43209876543209874
# Precision: 0.2222222222222222
# Recall: 0.1111111111111111
# F1-Score: 0.14814814814814814
#
# =========================================================================================
# Train Epoch: 37	 Learning rate: 0.0000	Loss: 18.449624	 Accuracy: 142/213 (67%)
#
# Confusion Matrix:
# [[ 4 14]
#  [32 31]]
# Accuracy: 0.43209876543209874
# Precision: 0.2222222222222222
# Recall: 0.1111111111111111
# F1-Score: 0.14814814814814814
#
# =========================================================================================
# Train Epoch: 38	 Learning rate: 0.0000	Loss: 18.403524	 Accuracy: 155/213 (73%)
#
# Confusion Matrix:
# [[ 4 16]
#  [32 29]]
# Accuracy: 0.4074074074074074
# Precision: 0.2
# Recall: 0.1111111111111111
# F1-Score: 0.14285714285714285
#
# =========================================================================================
# Train Epoch: 39	 Learning rate: 0.0000	Loss: 18.467465	 Accuracy: 150/213 (70%)
#
# Confusion Matrix:
# [[ 6 17]
#  [30 28]]
# Accuracy: 0.41975308641975306
# Precision: 0.2608695652173913
# Recall: 0.16666666666666666
# F1-Score: 0.20338983050847456
#
# =========================================================================================
# Train Epoch: 40	 Learning rate: 0.0000	Loss: 18.401206	 Accuracy: 162/213 (76%)
#
# Confusion Matrix:
# [[ 6 17]
#  [30 28]]
# Accuracy: 0.41975308641975306
# Precision: 0.2608695652173913
# Recall: 0.16666666666666666
# F1-Score: 0.20338983050847456
#
# =========================================================================================
# Train Epoch: 41	 Learning rate: 0.0000	Loss: 18.477839	 Accuracy: 149/213 (70%)
#
# Confusion Matrix:
# [[ 6 17]
#  [30 28]]
# Accuracy: 0.41975308641975306
# Precision: 0.2608695652173913
# Recall: 0.16666666666666666
# F1-Score: 0.20338983050847456
#
# =========================================================================================
# Train Epoch: 42	 Learning rate: 0.0000	Loss: 18.407014	 Accuracy: 158/213 (74%)
#
# Confusion Matrix:
# [[ 6 19]
#  [30 26]]
# Accuracy: 0.3950617283950617
# Precision: 0.24
# Recall: 0.16666666666666666
# F1-Score: 0.19672131147540983
#
# =========================================================================================
# Train Epoch: 43	 Learning rate: 0.0000	Loss: 18.366888	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[ 6 20]
#  [30 25]]
# Accuracy: 0.38271604938271603
# Precision: 0.23076923076923078
# Recall: 0.16666666666666666
# F1-Score: 0.1935483870967742
#
# =========================================================================================
# Train Epoch: 44	 Learning rate: 0.0000	Loss: 18.392548	 Accuracy: 153/213 (72%)
#
# Confusion Matrix:
# [[ 6 20]
#  [30 25]]
# Accuracy: 0.38271604938271603
# Precision: 0.23076923076923078
# Recall: 0.16666666666666666
# F1-Score: 0.1935483870967742
#
# =========================================================================================
# Train Epoch: 45	 Learning rate: 0.0000	Loss: 18.322729	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[ 6 21]
#  [30 24]]
# Accuracy: 0.37037037037037035
# Precision: 0.2222222222222222
# Recall: 0.16666666666666666
# F1-Score: 0.1904761904761905
#
# =========================================================================================
# Train Epoch: 46	 Learning rate: 0.0000	Loss: 18.350578	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[ 7 22]
#  [29 23]]
# Accuracy: 0.37037037037037035
# Precision: 0.2413793103448276
# Recall: 0.19444444444444445
# F1-Score: 0.21538461538461537
#
# =========================================================================================
# Train Epoch: 47	 Learning rate: 0.0000	Loss: 18.289561	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[ 8 22]
#  [28 23]]
# Accuracy: 0.38271604938271603
# Precision: 0.26666666666666666
# Recall: 0.2222222222222222
# F1-Score: 0.2424242424242424
#
# =========================================================================================
# Train Epoch: 48	 Learning rate: 0.0000	Loss: 18.308861	 Accuracy: 162/213 (76%)
#
# Confusion Matrix:
# [[ 8 22]
#  [28 23]]
# Accuracy: 0.38271604938271603
# Precision: 0.26666666666666666
# Recall: 0.2222222222222222
# F1-Score: 0.2424242424242424
#
# =========================================================================================
# Train Epoch: 49	 Learning rate: 0.0000	Loss: 18.209194	 Accuracy: 169/213 (79%)
#
# Confusion Matrix:
# [[ 8 23]
#  [28 22]]
# Accuracy: 0.37037037037037035
# Precision: 0.25806451612903225
# Recall: 0.2222222222222222
# F1-Score: 0.2388059701492537
#
# =========================================================================================
# Train Epoch: 50	 Learning rate: 0.0000	Loss: 18.288755	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[ 8 23]
#  [28 22]]
# Accuracy: 0.37037037037037035
# Precision: 0.25806451612903225
# Recall: 0.2222222222222222
# F1-Score: 0.2388059701492537
#
# =========================================================================================
# Train Epoch: 51	 Learning rate: 0.0000	Loss: 18.191622	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[ 8 23]
#  [28 22]]
# Accuracy: 0.37037037037037035
# Precision: 0.25806451612903225
# Recall: 0.2222222222222222
# F1-Score: 0.2388059701492537
#
# =========================================================================================
# Train Epoch: 52	 Learning rate: 0.0000	Loss: 18.221356	 Accuracy: 171/213 (80%)
#
# Confusion Matrix:
# [[ 9 26]
#  [27 19]]
# Accuracy: 0.345679012345679
# Precision: 0.2571428571428571
# Recall: 0.25
# F1-Score: 0.2535211267605634
#
# =========================================================================================
# Train Epoch: 53	 Learning rate: 0.0000	Loss: 18.195568	 Accuracy: 160/213 (75%)
#
# Confusion Matrix:
# [[ 9 28]
#  [27 17]]
# Accuracy: 0.32098765432098764
# Precision: 0.24324324324324326
# Recall: 0.25
# F1-Score: 0.24657534246575344
#
# =========================================================================================
# Train Epoch: 54	 Learning rate: 0.0000	Loss: 18.220181	 Accuracy: 154/213 (72%)
#
# Confusion Matrix:
# [[11 28]
#  [25 17]]
# Accuracy: 0.345679012345679
# Precision: 0.28205128205128205
# Recall: 0.3055555555555556
# F1-Score: 0.29333333333333333
#
# =========================================================================================
# Train Epoch: 55	 Learning rate: 0.0000	Loss: 18.132790	 Accuracy: 174/213 (82%)
#
# Confusion Matrix:
# [[11 30]
#  [25 15]]
# Accuracy: 0.32098765432098764
# Precision: 0.2682926829268293
# Recall: 0.3055555555555556
# F1-Score: 0.28571428571428575
#
# =========================================================================================
# Train Epoch: 56	 Learning rate: 0.0000	Loss: 18.204130	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[12 30]
#  [24 15]]
# Accuracy: 0.3333333333333333
# Precision: 0.2857142857142857
# Recall: 0.3333333333333333
# F1-Score: 0.30769230769230765
#
# =========================================================================================
# Train Epoch: 57	 Learning rate: 0.0000	Loss: 18.147007	 Accuracy: 161/213 (76%)
#
# Confusion Matrix:
# [[12 30]
#  [24 15]]
# Accuracy: 0.3333333333333333
# Precision: 0.2857142857142857
# Recall: 0.3333333333333333
# F1-Score: 0.30769230769230765
#
# =========================================================================================
# Train Epoch: 58	 Learning rate: 0.0000	Loss: 18.150403	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[13 31]
#  [23 14]]
# Accuracy: 0.3333333333333333
# Precision: 0.29545454545454547
# Recall: 0.3611111111111111
# F1-Score: 0.325
#
# =========================================================================================
# Train Epoch: 59	 Learning rate: 0.0000	Loss: 18.122536	 Accuracy: 163/213 (77%)
#
# Confusion Matrix:
# [[13 31]
#  [23 14]]
# Accuracy: 0.3333333333333333
# Precision: 0.29545454545454547
# Recall: 0.3611111111111111
# F1-Score: 0.325
#
# =========================================================================================
# Train Epoch: 60	 Learning rate: 0.0000	Loss: 18.090603	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[13 31]
#  [23 14]]
# Accuracy: 0.3333333333333333
# Precision: 0.29545454545454547
# Recall: 0.3611111111111111
# F1-Score: 0.325
#
# =========================================================================================
# Train Epoch: 61	 Learning rate: 0.0000	Loss: 18.032667	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[14 32]
#  [22 13]]
# Accuracy: 0.3333333333333333
# Precision: 0.30434782608695654
# Recall: 0.3888888888888889
# F1-Score: 0.34146341463414637
#
# =========================================================================================
# Train Epoch: 62	 Learning rate: 0.0000	Loss: 18.050780	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[14 32]
#  [22 13]]
# Accuracy: 0.3333333333333333
# Precision: 0.30434782608695654
# Recall: 0.3888888888888889
# F1-Score: 0.34146341463414637
#
# =========================================================================================
# Train Epoch: 63	 Learning rate: 0.0000	Loss: 17.988986	 Accuracy: 160/213 (75%)
#
# Confusion Matrix:
# [[14 32]
#  [22 13]]
# Accuracy: 0.3333333333333333
# Precision: 0.30434782608695654
# Recall: 0.3888888888888889
# F1-Score: 0.34146341463414637
#
# =========================================================================================
# Train Epoch: 64	 Learning rate: 0.0000	Loss: 17.969994	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[15 32]
#  [21 13]]
# Accuracy: 0.345679012345679
# Precision: 0.3191489361702128
# Recall: 0.4166666666666667
# F1-Score: 0.3614457831325302
#
# =========================================================================================
# Train Epoch: 65	 Learning rate: 0.0000	Loss: 17.963476	 Accuracy: 167/213 (78%)
#
# Confusion Matrix:
# [[15 33]
#  [21 12]]
# Accuracy: 0.3333333333333333
# Precision: 0.3125
# Recall: 0.4166666666666667
# F1-Score: 0.35714285714285715
#
# =========================================================================================
# Train Epoch: 66	 Learning rate: 0.0000	Loss: 17.861744	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[15 34]
#  [21 11]]
# Accuracy: 0.32098765432098764
# Precision: 0.30612244897959184
# Recall: 0.4166666666666667
# F1-Score: 0.35294117647058826
#
# =========================================================================================
# Train Epoch: 67	 Learning rate: 0.0000	Loss: 17.899591	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[15 34]
#  [21 11]]
# Accuracy: 0.32098765432098764
# Precision: 0.30612244897959184
# Recall: 0.4166666666666667
# F1-Score: 0.35294117647058826
#
# =========================================================================================
# Train Epoch: 68	 Learning rate: 0.0000	Loss: 17.886111	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[15 34]
#  [21 11]]
# Accuracy: 0.32098765432098764
# Precision: 0.30612244897959184
# Recall: 0.4166666666666667
# F1-Score: 0.35294117647058826
#
# =========================================================================================
# Train Epoch: 69	 Learning rate: 0.0000	Loss: 17.801920	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[15 34]
#  [21 11]]
# Accuracy: 0.32098765432098764
# Precision: 0.30612244897959184
# Recall: 0.4166666666666667
# F1-Score: 0.35294117647058826
#
# =========================================================================================
# Train Epoch: 70	 Learning rate: 0.0000	Loss: 17.827828	 Accuracy: 169/213 (79%)
#
# Confusion Matrix:
# [[16 34]
#  [20 11]]
# Accuracy: 0.3333333333333333
# Precision: 0.32
# Recall: 0.4444444444444444
# F1-Score: 0.37209302325581395
#
# =========================================================================================
# Train Epoch: 71	 Learning rate: 0.0000	Loss: 17.771368	 Accuracy: 167/213 (78%)
#
# Confusion Matrix:
# [[16 34]
#  [20 11]]
# Accuracy: 0.3333333333333333
# Precision: 0.32
# Recall: 0.4444444444444444
# F1-Score: 0.37209302325581395
#
# =========================================================================================
# Train Epoch: 72	 Learning rate: 0.0000	Loss: 17.710364	 Accuracy: 163/213 (77%)
#
# Confusion Matrix:
# [[17 34]
#  [19 11]]
# Accuracy: 0.345679012345679
# Precision: 0.3333333333333333
# Recall: 0.4722222222222222
# F1-Score: 0.39080459770114934
#
# =========================================================================================
# Train Epoch: 73	 Learning rate: 0.0000	Loss: 17.683772	 Accuracy: 169/213 (79%)
#
# Confusion Matrix:
# [[20 34]
#  [16 11]]
# Accuracy: 0.38271604938271603
# Precision: 0.37037037037037035
# Recall: 0.5555555555555556
# F1-Score: 0.4444444444444445
#
# =========================================================================================
# Train Epoch: 74	 Learning rate: 0.0000	Loss: 17.673035	 Accuracy: 158/213 (74%)
#
# Confusion Matrix:
# [[20 34]
#  [16 11]]
# Accuracy: 0.38271604938271603
# Precision: 0.37037037037037035
# Recall: 0.5555555555555556
# F1-Score: 0.4444444444444445
#
# =========================================================================================
# Train Epoch: 75	 Learning rate: 0.0000	Loss: 17.626652	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[20 34]
#  [16 11]]
# Accuracy: 0.38271604938271603
# Precision: 0.37037037037037035
# Recall: 0.5555555555555556
# F1-Score: 0.4444444444444445
#
# =========================================================================================
# Train Epoch: 76	 Learning rate: 0.0000	Loss: 17.668899	 Accuracy: 162/213 (76%)
#
# Confusion Matrix:
# [[20 34]
#  [16 11]]
# Accuracy: 0.38271604938271603
# Precision: 0.37037037037037035
# Recall: 0.5555555555555556
# F1-Score: 0.4444444444444445
#
# =========================================================================================
# Train Epoch: 77	 Learning rate: 0.0000	Loss: 17.478575	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[23 34]
#  [13 11]]
# Accuracy: 0.41975308641975306
# Precision: 0.40350877192982454
# Recall: 0.6388888888888888
# F1-Score: 0.49462365591397844
#
# =========================================================================================
# Train Epoch: 78	 Learning rate: 0.0000	Loss: 17.415695	 Accuracy: 167/213 (78%)
#
# Confusion Matrix:
# [[23 34]
#  [13 11]]
# Accuracy: 0.41975308641975306
# Precision: 0.40350877192982454
# Recall: 0.6388888888888888
# F1-Score: 0.49462365591397844
#
# =========================================================================================
# Train Epoch: 79	 Learning rate: 0.0000	Loss: 17.436924	 Accuracy: 171/213 (80%)
#
# Confusion Matrix:
# [[23 35]
#  [13 10]]
# Accuracy: 0.4074074074074074
# Precision: 0.39655172413793105
# Recall: 0.6388888888888888
# F1-Score: 0.48936170212765956
#
# =========================================================================================
# Train Epoch: 80	 Learning rate: 0.0000	Loss: 17.402244	 Accuracy: 161/213 (76%)
#
# Confusion Matrix:
# [[23 35]
#  [13 10]]
# Accuracy: 0.4074074074074074
# Precision: 0.39655172413793105
# Recall: 0.6388888888888888
# F1-Score: 0.48936170212765956
#
# =========================================================================================
# Train Epoch: 81	 Learning rate: 0.0000	Loss: 17.331312	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[23 35]
#  [13 10]]
# Accuracy: 0.4074074074074074
# Precision: 0.39655172413793105
# Recall: 0.6388888888888888
# F1-Score: 0.48936170212765956
#
# =========================================================================================
# Train Epoch: 82	 Learning rate: 0.0000	Loss: 17.224842	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[23 35]
#  [13 10]]
# Accuracy: 0.4074074074074074
# Precision: 0.39655172413793105
# Recall: 0.6388888888888888
# F1-Score: 0.48936170212765956
#
# =========================================================================================
# Train Epoch: 83	 Learning rate: 0.0000	Loss: 17.224244	 Accuracy: 163/213 (77%)
#
# Confusion Matrix:
# [[23 36]
#  [13  9]]
# Accuracy: 0.3950617283950617
# Precision: 0.3898305084745763
# Recall: 0.6388888888888888
# F1-Score: 0.4842105263157894
#
# =========================================================================================
# Train Epoch: 84	 Learning rate: 0.0000	Loss: 17.143717	 Accuracy: 161/213 (76%)
#
# Confusion Matrix:
# [[23 36]
#  [13  9]]
# Accuracy: 0.3950617283950617
# Precision: 0.3898305084745763
# Recall: 0.6388888888888888
# F1-Score: 0.4842105263157894
#
# =========================================================================================
# Train Epoch: 85	 Learning rate: 0.0000	Loss: 17.103816	 Accuracy: 159/213 (75%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 86	 Learning rate: 0.0000	Loss: 17.073053	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 87	 Learning rate: 0.0000	Loss: 17.017143	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 88	 Learning rate: 0.0000	Loss: 16.832849	 Accuracy: 160/213 (75%)
#
# Confusion Matrix:
# [[24 38]
#  [12  7]]
# Accuracy: 0.38271604938271603
# Precision: 0.3870967741935484
# Recall: 0.6666666666666666
# F1-Score: 0.4897959183673469
#
# =========================================================================================
# Train Epoch: 89	 Learning rate: 0.0000	Loss: 16.896994	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[24 38]
#  [12  7]]
# Accuracy: 0.38271604938271603
# Precision: 0.3870967741935484
# Recall: 0.6666666666666666
# F1-Score: 0.4897959183673469
#
# =========================================================================================
# Train Epoch: 90	 Learning rate: 0.0000	Loss: 16.835651	 Accuracy: 158/213 (74%)
#
# Confusion Matrix:
# [[24 38]
#  [12  7]]
# Accuracy: 0.38271604938271603
# Precision: 0.3870967741935484
# Recall: 0.6666666666666666
# F1-Score: 0.4897959183673469
#
# =========================================================================================
# Train Epoch: 91	 Learning rate: 0.0000	Loss: 16.778328	 Accuracy: 157/213 (74%)
#
# Confusion Matrix:
# [[24 38]
#  [12  7]]
# Accuracy: 0.38271604938271603
# Precision: 0.3870967741935484
# Recall: 0.6666666666666666
# F1-Score: 0.4897959183673469
#
# =========================================================================================
# Train Epoch: 92	 Learning rate: 0.0000	Loss: 16.640274	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[25 38]
#  [11  7]]
# Accuracy: 0.3950617283950617
# Precision: 0.3968253968253968
# Recall: 0.6944444444444444
# F1-Score: 0.5050505050505051
#
# =========================================================================================
# Train Epoch: 93	 Learning rate: 0.0000	Loss: 16.614678	 Accuracy: 160/213 (75%)
#
# Confusion Matrix:
# [[25 38]
#  [11  7]]
# Accuracy: 0.3950617283950617
# Precision: 0.3968253968253968
# Recall: 0.6944444444444444
# F1-Score: 0.5050505050505051
#
# =========================================================================================
# Train Epoch: 94	 Learning rate: 0.0000	Loss: 16.658150	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[25 38]
#  [11  7]]
# Accuracy: 0.3950617283950617
# Precision: 0.3968253968253968
# Recall: 0.6944444444444444
# F1-Score: 0.5050505050505051
#
# =========================================================================================
# Train Epoch: 95	 Learning rate: 0.0000	Loss: 16.434175	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[25 38]
#  [11  7]]
# Accuracy: 0.3950617283950617
# Precision: 0.3968253968253968
# Recall: 0.6944444444444444
# F1-Score: 0.5050505050505051
#
# =========================================================================================
# Train Epoch: 96	 Learning rate: 0.0000	Loss: 16.444222	 Accuracy: 164/213 (77%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 97	 Learning rate: 0.0000	Loss: 16.451802	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 98	 Learning rate: 0.0000	Loss: 16.371674	 Accuracy: 163/213 (77%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 99	 Learning rate: 0.0000	Loss: 16.172517	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 100	 Learning rate: 0.0000	Loss: 16.055004	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 101	 Learning rate: 0.0000	Loss: 15.976305	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 102	 Learning rate: 0.0000	Loss: 15.904746	 Accuracy: 163/213 (77%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 103	 Learning rate: 0.0000	Loss: 15.851880	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 104	 Learning rate: 0.0000	Loss: 15.805804	 Accuracy: 167/213 (78%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 105	 Learning rate: 0.0000	Loss: 15.831033	 Accuracy: 163/213 (77%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 106	 Learning rate: 0.0000	Loss: 15.677291	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 107	 Learning rate: 0.0000	Loss: 15.587401	 Accuracy: 167/213 (78%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 108	 Learning rate: 0.0000	Loss: 15.541994	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 109	 Learning rate: 0.0000	Loss: 15.551901	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[26 38]
#  [10  7]]
# Accuracy: 0.4074074074074074
# Precision: 0.40625
# Recall: 0.7222222222222222
# F1-Score: 0.52
#
# =========================================================================================
# Train Epoch: 110	 Learning rate: 0.0000	Loss: 15.360281	 Accuracy: 167/213 (78%)
#
# Confusion Matrix:
# [[26 37]
#  [10  8]]
# Accuracy: 0.41975308641975306
# Precision: 0.4126984126984127
# Recall: 0.7222222222222222
# F1-Score: 0.5252525252525252
#
# =========================================================================================
# Train Epoch: 111	 Learning rate: 0.0000	Loss: 15.240110	 Accuracy: 169/213 (79%)
#
# Confusion Matrix:
# [[26 37]
#  [10  8]]
# Accuracy: 0.41975308641975306
# Precision: 0.4126984126984127
# Recall: 0.7222222222222222
# F1-Score: 0.5252525252525252
#
# =========================================================================================
# Train Epoch: 112	 Learning rate: 0.0000	Loss: 15.231178	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[26 37]
#  [10  8]]
# Accuracy: 0.41975308641975306
# Precision: 0.4126984126984127
# Recall: 0.7222222222222222
# F1-Score: 0.5252525252525252
#
# =========================================================================================
# Train Epoch: 113	 Learning rate: 0.0000	Loss: 15.128366	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[26 37]
#  [10  8]]
# Accuracy: 0.41975308641975306
# Precision: 0.4126984126984127
# Recall: 0.7222222222222222
# F1-Score: 0.5252525252525252
#
# =========================================================================================
# Train Epoch: 114	 Learning rate: 0.0000	Loss: 15.048316	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 115	 Learning rate: 0.0000	Loss: 15.056077	 Accuracy: 173/213 (81%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 116	 Learning rate: 0.0000	Loss: 14.854087	 Accuracy: 175/213 (82%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 117	 Learning rate: 0.0000	Loss: 14.897446	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 118	 Learning rate: 0.0000	Loss: 14.780369	 Accuracy: 176/213 (83%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 119	 Learning rate: 0.0000	Loss: 14.683870	 Accuracy: 175/213 (82%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 120	 Learning rate: 0.0000	Loss: 14.584038	 Accuracy: 176/213 (83%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 121	 Learning rate: 0.0000	Loss: 14.447570	 Accuracy: 172/213 (81%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 122	 Learning rate: 0.0000	Loss: 14.481278	 Accuracy: 173/213 (81%)
#
# Confusion Matrix:
# [[25 37]
#  [11  8]]
# Accuracy: 0.4074074074074074
# Precision: 0.4032258064516129
# Recall: 0.6944444444444444
# F1-Score: 0.5102040816326531
#
# =========================================================================================
# Train Epoch: 123	 Learning rate: 0.0000	Loss: 14.411807	 Accuracy: 180/213 (85%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 124	 Learning rate: 0.0000	Loss: 14.337312	 Accuracy: 179/213 (84%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 125	 Learning rate: 0.0000	Loss: 14.318237	 Accuracy: 178/213 (84%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 126	 Learning rate: 0.0000	Loss: 14.182255	 Accuracy: 184/213 (86%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 127	 Learning rate: 0.0000	Loss: 14.171987	 Accuracy: 180/213 (85%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 128	 Learning rate: 0.0000	Loss: 14.064369	 Accuracy: 180/213 (85%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 129	 Learning rate: 0.0000	Loss: 13.989947	 Accuracy: 176/213 (83%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 130	 Learning rate: 0.0000	Loss: 14.041961	 Accuracy: 183/213 (86%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 131	 Learning rate: 0.0000	Loss: 13.803092	 Accuracy: 186/213 (87%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 132	 Learning rate: 0.0000	Loss: 13.695141	 Accuracy: 182/213 (85%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 133	 Learning rate: 0.0000	Loss: 13.683741	 Accuracy: 186/213 (87%)
#
# Confusion Matrix:
# [[24 37]
#  [12  8]]
# Accuracy: 0.3950617283950617
# Precision: 0.39344262295081966
# Recall: 0.6666666666666666
# F1-Score: 0.4948453608247423
#
# =========================================================================================
# Train Epoch: 134	 Learning rate: 0.0000	Loss: 13.708407	 Accuracy: 182/213 (85%)
#
# Confusion Matrix:
# [[24 36]
#  [12  9]]
# Accuracy: 0.4074074074074074
# Precision: 0.4
# Recall: 0.6666666666666666
# F1-Score: 0.5
#
# =========================================================================================
# Train Epoch: 135	 Learning rate: 0.0000	Loss: 13.501353	 Accuracy: 191/213 (90%)
#
# Confusion Matrix:
# [[24 36]
#  [12  9]]
# Accuracy: 0.4074074074074074
# Precision: 0.4
# Recall: 0.6666666666666666
# F1-Score: 0.5
#
# =========================================================================================
# Train Epoch: 136	 Learning rate: 0.0000	Loss: 13.551349	 Accuracy: 180/213 (85%)
#
# Confusion Matrix:
# [[24 36]
#  [12  9]]
# Accuracy: 0.4074074074074074
# Precision: 0.4
# Recall: 0.6666666666666666
# F1-Score: 0.5
#
# =========================================================================================
# Train Epoch: 137	 Learning rate: 0.0000	Loss: 13.541200	 Accuracy: 179/213 (84%)
#
# Confusion Matrix:
# [[24 36]
#  [12  9]]
# Accuracy: 0.4074074074074074
# Precision: 0.4
# Recall: 0.6666666666666666
# F1-Score: 0.5
#
# =========================================================================================
# ...
# Accuracy: 0.5057471264367817
# Precision: 0.5074626865671642
# Recall: 0.7727272727272727
# F1-Score: 0.6126126126126127
#
# =========================================================================================
# Train Epoch: 122	 Learning rate: 0.0000	Loss: 14.926353	 Accuracy: 163/203 (80%)
#
# Confusion Matrix:
# [[34 33]
#  [10 10]]
# Accuracy: 0.5057471264367817
# Precision: 0.5074626865671642
# Recall: 0.7727272727272727
# F1-Score: 0.6126126126126127
#
# =========================================================================================
# Train Epoch: 123	 Learning rate: 0.0000	Loss: 14.853963	 Accuracy: 161/203 (79%)
#
# Confusion Matrix:
# [[33 31]
#  [11 12]]
# Accuracy: 0.5172413793103449
# Precision: 0.515625
# Recall: 0.75
# F1-Score: 0.6111111111111112
#
# =========================================================================================
# Train Epoch: 124	 Learning rate: 0.0000	Loss: 14.792759	 Accuracy: 163/203 (80%)
#
# Confusion Matrix:
# [[33 31]
#  [11 12]]
# Accuracy: 0.5172413793103449
# Precision: 0.515625
# Recall: 0.75
# F1-Score: 0.6111111111111112
#
# =========================================================================================
# Train Epoch: 125	 Learning rate: 0.0000	Loss: 14.622588	 Accuracy: 163/203 (80%)
#
# Confusion Matrix:
# [[33 31]
#  [11 12]]
# Accuracy: 0.5172413793103449
# Precision: 0.515625
# Recall: 0.75
# F1-Score: 0.6111111111111112
#
# =========================================================================================
# Train Epoch: 126	 Learning rate: 0.0000	Loss: 14.583359	 Accuracy: 164/203 (81%)
#
# Confusion Matrix:
# [[32 31]
#  [12 12]]
# Accuracy: 0.5057471264367817
# Precision: 0.5079365079365079
# Recall: 0.7272727272727273
# F1-Score: 0.5981308411214953
#
# =========================================================================================
# Train Epoch: 127	 Learning rate: 0.0000	Loss: 14.533848	 Accuracy: 171/203 (84%)
#
# Confusion Matrix:
# [[32 31]
#  [12 12]]
# Accuracy: 0.5057471264367817
# Precision: 0.5079365079365079
# Recall: 0.7272727272727273
# F1-Score: 0.5981308411214953
#
# =========================================================================================
# Train Epoch: 128	 Learning rate: 0.0000	Loss: 14.464689	 Accuracy: 174/203 (86%)
#
# Confusion Matrix:
# [[32 31]
#  [12 12]]
# Accuracy: 0.5057471264367817
# Precision: 0.5079365079365079
# Recall: 0.7272727272727273
# F1-Score: 0.5981308411214953
#
# =========================================================================================
# Train Epoch: 129	 Learning rate: 0.0000	Loss: 14.324013	 Accuracy: 169/203 (83%)
#
# Confusion Matrix:
# [[32 31]
#  [12 12]]
# Accuracy: 0.5057471264367817
# Precision: 0.5079365079365079
# Recall: 0.7272727272727273
# F1-Score: 0.5981308411214953
#
# =========================================================================================
# Train Epoch: 130	 Learning rate: 0.0000	Loss: 14.289301	 Accuracy: 167/203 (82%)
#
# Confusion Matrix:
# [[32 30]
#  [12 13]]
# Accuracy: 0.5172413793103449
# Precision: 0.5161290322580645
# Recall: 0.7272727272727273
# F1-Score: 0.6037735849056604
#
# =========================================================================================
# Train Epoch: 131	 Learning rate: 0.0000	Loss: 14.433287	 Accuracy: 161/203 (79%)
#
# Confusion Matrix:
# [[32 29]
#  [12 14]]
# Accuracy: 0.5287356321839081
# Precision: 0.5245901639344263
# Recall: 0.7272727272727273
# F1-Score: 0.6095238095238097
#
# =========================================================================================
# Train Epoch: 132	 Learning rate: 0.0000	Loss: 14.205991	 Accuracy: 168/203 (83%)
#
# Confusion Matrix:
# [[32 29]
#  [12 14]]
# Accuracy: 0.5287356321839081
# Precision: 0.5245901639344263
# Recall: 0.7272727272727273
# F1-Score: 0.6095238095238097
#
# =========================================================================================
# Train Epoch: 133	 Learning rate: 0.0000	Loss: 13.982556	 Accuracy: 174/203 (86%)
#
# Confusion Matrix:
# [[32 29]
#  [12 14]]
# Accuracy: 0.5287356321839081
# Precision: 0.5245901639344263
# Recall: 0.7272727272727273
# F1-Score: 0.6095238095238097
#
# =========================================================================================
# Train Epoch: 134	 Learning rate: 0.0000	Loss: 14.171970	 Accuracy: 171/203 (84%)
#
# Confusion Matrix:
# [[32 29]
#  [12 14]]
# Accuracy: 0.5287356321839081
# Precision: 0.5245901639344263
# Recall: 0.7272727272727273
# F1-Score: 0.6095238095238097
#
# =========================================================================================
# Train Epoch: 135	 Learning rate: 0.0000	Loss: 13.975823	 Accuracy: 173/203 (85%)
#
# Confusion Matrix:
# [[30 29]
#  [14 14]]
# Accuracy: 0.5057471264367817
# Precision: 0.5084745762711864
# Recall: 0.6818181818181818
# F1-Score: 0.5825242718446602
#
# =========================================================================================
# Train Epoch: 136	 Learning rate: 0.0000	Loss: 13.901063	 Accuracy: 170/203 (84%)
#
# Confusion Matrix:
# [[29 29]
#  [15 14]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.6590909090909091
# F1-Score: 0.5686274509803921
#
# =========================================================================================
# Train Epoch: 137	 Learning rate: 0.0000	Loss: 13.769335	 Accuracy: 175/203 (86%)
#
# Confusion Matrix:
# [[29 29]
#  [15 14]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.6590909090909091
# F1-Score: 0.5686274509803921
#
# =========================================================================================
# Train Epoch: 138	 Learning rate: 0.0000	Loss: 13.874121	 Accuracy: 177/203 (87%)
#
# Confusion Matrix:
# [[29 28]
#  [15 15]]
# Accuracy: 0.5057471264367817
# Precision: 0.5087719298245614
# Recall: 0.6590909090909091
# F1-Score: 0.5742574257425743
#
# =========================================================================================
# Train Epoch: 139	 Learning rate: 0.0000	Loss: 13.622831	 Accuracy: 171/203 (84%)
#
# Confusion Matrix:
# [[29 28]
#  [15 15]]
# Accuracy: 0.5057471264367817
# Precision: 0.5087719298245614
# Recall: 0.6590909090909091
# F1-Score: 0.5742574257425743
#
# =========================================================================================
# Train Epoch: 140	 Learning rate: 0.0000	Loss: 13.620984	 Accuracy: 177/203 (87%)
#
# Confusion Matrix:
# [[28 28]
#  [16 15]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.6363636363636364
# F1-Score: 0.56
#
# =========================================================================================
# Train Epoch: 141	 Learning rate: 0.0000	Loss: 13.612026	 Accuracy: 171/203 (84%)
#
# Confusion Matrix:
# [[28 27]
#  [16 16]]
# Accuracy: 0.5057471264367817
# Precision: 0.509090909090909
# Recall: 0.6363636363636364
# F1-Score: 0.5656565656565656
#
# =========================================================================================
# Train Epoch: 142	 Learning rate: 0.0000	Loss: 13.470153	 Accuracy: 181/203 (89%)
#
# Confusion Matrix:
# [[28 26]
#  [16 17]]
# Accuracy: 0.5172413793103449
# Precision: 0.5185185185185185
# Recall: 0.6363636363636364
# F1-Score: 0.5714285714285714
#
# =========================================================================================
# Train Epoch: 143	 Learning rate: 0.0000	Loss: 13.359746	 Accuracy: 183/203 (90%)
#
# Confusion Matrix:
# [[27 26]
#  [17 17]]
# Accuracy: 0.5057471264367817
# Precision: 0.5094339622641509
# Recall: 0.6136363636363636
# F1-Score: 0.556701030927835
#
# =========================================================================================
# Train Epoch: 144	 Learning rate: 0.0000	Loss: 13.189074	 Accuracy: 184/203 (91%)
#
# Confusion Matrix:
# [[27 26]
#  [17 17]]
# Accuracy: 0.5057471264367817
# Precision: 0.5094339622641509
# Recall: 0.6136363636363636
# F1-Score: 0.556701030927835
#
# =========================================================================================
# Train Epoch: 145	 Learning rate: 0.0000	Loss: 13.153082	 Accuracy: 179/203 (88%)
#
# Confusion Matrix:
# [[27 26]
#  [17 17]]
# Accuracy: 0.5057471264367817
# Precision: 0.5094339622641509
# Recall: 0.6136363636363636
# F1-Score: 0.556701030927835
#
# =========================================================================================
# Train Epoch: 146	 Learning rate: 0.0000	Loss: 13.012273	 Accuracy: 184/203 (91%)
#
# Confusion Matrix:
# [[27 26]
#  [17 17]]
# Accuracy: 0.5057471264367817
# Precision: 0.5094339622641509
# Recall: 0.6136363636363636
# F1-Score: 0.556701030927835
#
# =========================================================================================
# Train Epoch: 147	 Learning rate: 0.0000	Loss: 13.172791	 Accuracy: 183/203 (90%)
#
# Confusion Matrix:
# [[27 26]
#  [17 17]]
# Accuracy: 0.5057471264367817
# Precision: 0.5094339622641509
# Recall: 0.6136363636363636
# F1-Score: 0.556701030927835
#
# =========================================================================================
# Train Epoch: 148	 Learning rate: 0.0000	Loss: 13.059703	 Accuracy: 179/203 (88%)
#
# Confusion Matrix:
# [[25 26]
#  [19 17]]
# Accuracy: 0.4827586206896552
# Precision: 0.49019607843137253
# Recall: 0.5681818181818182
# F1-Score: 0.5263157894736843
#
# =========================================================================================
# Train Epoch: 149	 Learning rate: 0.0000	Loss: 12.982295	 Accuracy: 183/203 (90%)
#
# Confusion Matrix:
# [[25 26]
#  [19 17]]
# Accuracy: 0.4827586206896552
# Precision: 0.49019607843137253
# Recall: 0.5681818181818182
# F1-Score: 0.5263157894736843
#
# =========================================================================================
# Train Epoch: 150	 Learning rate: 0.0000	Loss: 12.840697	 Accuracy: 186/203 (92%)
#
# Confusion Matrix:
# [[25 26]
#  [19 17]]
# Accuracy: 0.4827586206896552
# Precision: 0.49019607843137253
# Recall: 0.5681818181818182
# F1-Score: 0.5263157894736843
#
# =========================================================================================
# Train Epoch: 151	 Learning rate: 0.0000	Loss: 12.805311	 Accuracy: 187/203 (92%)
#
# Confusion Matrix:
# [[25 26]
#  [19 17]]
# Accuracy: 0.4827586206896552
# Precision: 0.49019607843137253
# Recall: 0.5681818181818182
# F1-Score: 0.5263157894736843
#
# =========================================================================================
# Train Epoch: 152	 Learning rate: 0.0000	Loss: 12.680641	 Accuracy: 188/203 (93%)
#
# Confusion Matrix:
# [[24 26]
#  [20 17]]
# Accuracy: 0.47126436781609193
# Precision: 0.48
# Recall: 0.5454545454545454
# F1-Score: 0.5106382978723404
#
# =========================================================================================
# Train Epoch: 153	 Learning rate: 0.0000	Loss: 12.690566	 Accuracy: 185/203 (91%)
#
# Confusion Matrix:
# [[24 26]
#  [20 17]]
# Accuracy: 0.47126436781609193
# Precision: 0.48
# Recall: 0.5454545454545454
# F1-Score: 0.5106382978723404
#
# =========================================================================================
# Train Epoch: 154	 Learning rate: 0.0000	Loss: 12.573490	 Accuracy: 186/203 (92%)
#
# Confusion Matrix:
# [[24 26]
#  [20 17]]
# Accuracy: 0.47126436781609193
# Precision: 0.48
# Recall: 0.5454545454545454
# F1-Score: 0.5106382978723404
#
# =========================================================================================
# Train Epoch: 155	 Learning rate: 0.0000	Loss: 12.455550	 Accuracy: 189/203 (93%)
#
# Confusion Matrix:
# [[24 24]
#  [20 19]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.5454545454545454
# F1-Score: 0.5217391304347826
#
# =========================================================================================
# Train Epoch: 156	 Learning rate: 0.0000	Loss: 12.447798	 Accuracy: 191/203 (94%)
#
# Confusion Matrix:
# [[23 24]
#  [21 19]]
# Accuracy: 0.4827586206896552
# Precision: 0.48936170212765956
# Recall: 0.5227272727272727
# F1-Score: 0.5054945054945055
#
# =========================================================================================
# Train Epoch: 157	 Learning rate: 0.0000	Loss: 12.490341	 Accuracy: 188/203 (93%)
#
# Confusion Matrix:
# [[23 24]
#  [21 19]]
# Accuracy: 0.4827586206896552
# Precision: 0.48936170212765956
# Recall: 0.5227272727272727
# F1-Score: 0.5054945054945055
#
# =========================================================================================
# Train Epoch: 158	 Learning rate: 0.0000	Loss: 12.345225	 Accuracy: 189/203 (93%)
#
# Confusion Matrix:
# [[23 24]
#  [21 19]]
# Accuracy: 0.4827586206896552
# Precision: 0.48936170212765956
# Recall: 0.5227272727272727
# F1-Score: 0.5054945054945055
#
# =========================================================================================
# Train Epoch: 159	 Learning rate: 0.0000	Loss: 12.263303	 Accuracy: 191/203 (94%)
#
# Confusion Matrix:
# [[23 24]
#  [21 19]]
# Accuracy: 0.4827586206896552
# Precision: 0.48936170212765956
# Recall: 0.5227272727272727
# F1-Score: 0.5054945054945055
#
# =========================================================================================
# Train Epoch: 160	 Learning rate: 0.0000	Loss: 12.238374	 Accuracy: 189/203 (93%)
#
# Confusion Matrix:
# [[23 24]
#  [21 19]]
# Accuracy: 0.4827586206896552
# Precision: 0.48936170212765956
# Recall: 0.5227272727272727
# F1-Score: 0.5054945054945055
#
# =========================================================================================
# Train Epoch: 161	 Learning rate: 0.0000	Loss: 12.275092	 Accuracy: 192/203 (95%)
#
# Confusion Matrix:
# [[22 24]
#  [22 19]]
# Accuracy: 0.47126436781609193
# Precision: 0.4782608695652174
# Recall: 0.5
# F1-Score: 0.4888888888888889
#
# =========================================================================================
# Train Epoch: 162	 Learning rate: 0.0000	Loss: 12.090570	 Accuracy: 193/203 (95%)
#
# Confusion Matrix:
# [[21 24]
#  [23 19]]
# Accuracy: 0.45977011494252873
# Precision: 0.4666666666666667
# Recall: 0.4772727272727273
# F1-Score: 0.4719101123595506
#
# =========================================================================================
# Train Epoch: 163	 Learning rate: 0.0000	Loss: 12.035980	 Accuracy: 188/203 (93%)
#
# Confusion Matrix:
# [[21 24]
#  [23 19]]
# Accuracy: 0.45977011494252873
# Precision: 0.4666666666666667
# Recall: 0.4772727272727273
# F1-Score: 0.4719101123595506
#
# =========================================================================================
# Train Epoch: 164	 Learning rate: 0.0000	Loss: 11.927012	 Accuracy: 191/203 (94%)
#
# Confusion Matrix:
# [[20 24]
#  [24 19]]
# Accuracy: 0.4482758620689655
# Precision: 0.45454545454545453
# Recall: 0.45454545454545453
# F1-Score: 0.45454545454545453
#
# =========================================================================================
# Train Epoch: 165	 Learning rate: 0.0000	Loss: 11.965556	 Accuracy: 194/203 (96%)
#
# Confusion Matrix:
# [[20 23]
#  [24 20]]
# Accuracy: 0.45977011494252873
# Precision: 0.46511627906976744
# Recall: 0.45454545454545453
# F1-Score: 0.45977011494252873
#
# =========================================================================================
# Train Epoch: 166	 Learning rate: 0.0000	Loss: 11.819993	 Accuracy: 195/203 (96%)
#
# Confusion Matrix:
# [[20 23]
#  [24 20]]
# Accuracy: 0.45977011494252873
# Precision: 0.46511627906976744
# Recall: 0.45454545454545453
# F1-Score: 0.45977011494252873
#
# =========================================================================================
# Train Epoch: 167	 Learning rate: 0.0000	Loss: 11.798545	 Accuracy: 190/203 (94%)
#
# Confusion Matrix:
# [[19 23]
#  [25 20]]
# Accuracy: 0.4482758620689655
# Precision: 0.4523809523809524
# Recall: 0.4318181818181818
# F1-Score: 0.4418604651162791
#
# =========================================================================================
# Train Epoch: 168	 Learning rate: 0.0000	Loss: 11.578415	 Accuracy: 197/203 (97%)
#
# Confusion Matrix:
# [[19 23]
#  [25 20]]
# Accuracy: 0.4482758620689655
# Precision: 0.4523809523809524
# Recall: 0.4318181818181818
# F1-Score: 0.4418604651162791
#
# =========================================================================================
# Train Epoch: 169	 Learning rate: 0.0000	Loss: 11.656529	 Accuracy: 193/203 (95%)
#
# Confusion Matrix:
# [[19 22]
#  [25 21]]
# Accuracy: 0.45977011494252873
# Precision: 0.4634146341463415
# Recall: 0.4318181818181818
# F1-Score: 0.4470588235294118
#
# =========================================================================================
# Train Epoch: 170	 Learning rate: 0.0000	Loss: 11.462889	 Accuracy: 199/203 (98%)
#
# Confusion Matrix:
# [[17 22]
#  [27 21]]
# Accuracy: 0.4367816091954023
# Precision: 0.4358974358974359
# Recall: 0.38636363636363635
# F1-Score: 0.40963855421686746
#
# =========================================================================================
