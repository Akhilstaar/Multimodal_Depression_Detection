# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F
import torch.optim as optim
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

import numpy as np
import pandas as pd
import os
import pickle
import random
import itertools

# %%
config = {
    'num_classes': 2,
    'dropout': 0.5,
    'rnn_layers': 2,
    'embedding_size': 256,
    'batch_size': 8,
    'epochs': 170,
    'learning_rate': 6e-6,
    'hidden_dims': 256,
    'bidirectional': False,
    'cuda': False
}

prefix = os.path.abspath(os.path.join(os.getcwd(), ".."))
audio_features = np.squeeze(np.load(os.path.join(prefix, 'Features/AudioWhole/whole_samples_clf_256.npz'))['arr_0'], axis=2)
audio_targets = np.load(os.path.join(prefix, 'Features/AudioWhole/whole_labels_clf_256.npz'))['arr_0']
audio_dep_idxs_tmp = np.where(audio_targets == 1)[0]
audio_non_idxs = np.where(audio_targets == 0)[0]

# %%
class AudioBiLSTM(nn.Module):
    def __init__(self, config):
        super(AudioBiLSTM, self).__init__()
        self.num_classes = config['num_classes']
        self.learning_rate = config['learning_rate']
        self.dropout = config['dropout']
        self.hidden_dims = config['hidden_dims']
        self.rnn_layers = config['rnn_layers']
        self.embedding_size = config['embedding_size']
        self.bidirectional = config['bidirectional']

        self.build_model()

    def init_weight(net):
        for name, param in net.named_parameters():
            if not 'ln' in name:
                if 'bias' in name:
                    nn.init.constant_(param, 0.0)
                elif 'weight' in name:
                    nn.init.xavier_uniform_(param)

    def build_model(self):
        # attention layer
        self.attention_layer = nn.Sequential(
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(inplace=True))

        self.lstm_net_audio = nn.GRU(self.embedding_size, self.hidden_dims,
                                num_layers=self.rnn_layers, dropout=self.dropout, batch_first=True)

        self.ln = nn.LayerNorm(self.embedding_size)

        # FC
        self.fc_audio = nn.Sequential(
            nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(),
            nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.num_classes),
            nn.Softmax(dim=1)
        )

    def attention_net_with_w(self, lstm_out, lstm_hidden):
        '''
        :param lstm_out:    [batch_size, len_seq, n_hidden * 2]
        :param lstm_hidden: [batch_size, num_layers * num_directions, n_hidden]
        :return: [batch_size, n_hidden]
        '''
        lstm_tmp_out = torch.chunk(lstm_out, 2, -1)
        # h [batch_size, time_step, hidden_dims]
        h = lstm_tmp_out[0] + lstm_tmp_out[1]
        # h = lstm_out
        # [batch_size, num_layers * num_directions, n_hidden]
        lstm_hidden = torch.sum(lstm_hidden, dim=1)
        # [batch_size, 1, n_hidden]
        lstm_hidden = lstm_hidden.unsqueeze(1)
        # atten_w [batch_size, 1, hidden_dims]
        atten_w = self.attention_layer(lstm_hidden)
        # m [batch_size, time_step, hidden_dims]
        m = nn.Tanh()(h)
        # atten_context [batch_size, 1, time_step]
       # print(atten_w.shape, m.transpose(1, 2).shape)
        atten_context = torch.bmm(atten_w, m.transpose(1, 2))
        # softmax_w [batch_size, 1, time_step]
        softmax_w = F.softmax(atten_context, dim=-1)
        # context [batch_size, 1, hidden_dims]
        context = torch.bmm(softmax_w, h)
        result = context.squeeze(1)
        return result

    def forward(self, x):
        x = self.ln(x)
        x, _ = self.lstm_net_audio(x)
        x = x.mean(dim=1)
        out = self.fc_audio(x)
        return out

# %%
def save(model, filename):
    save_filename = '{}.pt'.format(filename)
    torch.save(model, save_filename)
    print('Saved as %s' % save_filename)

# %%
def standard_confusion_matrix(y_test, y_test_pred):
    """
    Make confusion matrix with format:
                  -----------
                  | TP | FP |
                  -----------
                  | FN | TN |
                  -----------
    Parameters
    ----------
    y_true : ndarray - 1D
    y_pred : ndarray - 1D

    Returns
    -------
    ndarray - 2D
    """
    [[tn, fp], [fn, tp]] = confusion_matrix(y_test.cpu().numpy(), y_test_pred)
    return np.array([[tp, fp], [fn, tn]])

def model_performance(y_test, y_test_pred_proba):
    """
    Evaluation metrics for network performance.
    """
    y_test_pred = y_test_pred_proba.data.max(1, keepdim=True)[1]

    # Computing confusion matrix for test dataset
    conf_matrix = standard_confusion_matrix(y_test, y_test_pred.numpy())
    print("Confusion Matrix:")
    print(conf_matrix)

    return y_test_pred, conf_matrix

def train(epoch, train_idxs):
    global lr, train_acc
    model.train()
    batch_idx = 1      
    total_loss = 0
    correct = 0
    pred = np.array([])
    X_train = audio_features[train_idxs]
    Y_train = audio_targets[train_idxs]
    for i in range(0, X_train.shape[0], config['batch_size']):
        if i + config['batch_size'] > X_train.shape[0]:
            x, y = X_train[i:], Y_train[i:]
        else:
            x, y = X_train[i:(i + config['batch_size'])], Y_train[i:(
                i + config['batch_size'])]
        if config['cuda']:
            x, y = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad=True).cuda(), Variable(torch.from_numpy(y)).cuda()
        else:
            x, y = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad=True), \
                Variable(torch.from_numpy(y))

        optimizer.zero_grad()
        output = model(x)
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(y.data.view_as(pred)).cpu().sum()
        y = y.long()
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        batch_idx += 1
        total_loss += loss.item()

    train_acc = correct
    print(
        'Train Epoch: {:2d}\t Learning rate: {:.4f}\tLoss: {:.6f}\t Accuracy: {}/{} ({:.0f}%)\n '
        .format(epoch + 1, config['learning_rate'], total_loss, correct,
                X_train.shape[0], 100. * correct / X_train.shape[0]))

# %%
def evaluate(model, test_idxs, fold, train_idxs_tmp, train_idxs):
    model.eval()
    batch_idx = 1
    total_loss = 0
    global max_f1, max_acc, min_mae, X_test_lens, max_prec, max_rec
    pred = np.array([])
    with torch.no_grad():
        if config['cuda']:
            x, y = Variable(torch.from_numpy(audio_features[test_idxs]).type(torch.FloatTensor), requires_grad=True).cuda(),\
                Variable(torch.from_numpy(audio_targets[test_idxs])).cuda()
        else:
            x, y = Variable(torch.from_numpy(audio_features[test_idxs]).type(torch.FloatTensor), requires_grad=True), \
                Variable(torch.from_numpy(audio_targets[test_idxs])).type(torch.LongTensor)

        optimizer.zero_grad()
        output = model(x)
        loss = criterion(output, y)
        total_loss += loss.item()
        y_test_pred, conf_matrix = model_performance(y, output.cpu())
        accuracy = float(conf_matrix[0][0] + conf_matrix[1][1]) / np.sum(conf_matrix)
        precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
        recall = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[1][0])
        f1_score = 2 * (precision * recall) / (precision + recall)
        print("Accuracy: {}".format(accuracy))
        print("Precision: {}".format(precision))
        print("Recall: {}".format(recall))
        print("F1-Score: {}\n".format(f1_score))
        print('=' * 89)

        if max_f1 <= f1_score and train_acc > len(train_idxs)*0.90  and f1_score > 0.5:
            max_f1 = f1_score
            max_acc = accuracy
            max_rec = recall
            max_prec = precision
            mode ='gru'
            save(model, os.path.join(prefix, 'Model/ClassificationWhole/Audio/BiLSTM_{}_vlad{}_{}_{:.2f}_{}'.format(mode, config['embedding_size'], config['hidden_dims'], max_f1, fold)))
            np.save(os.path.join(prefix, 'Features/TextWhole/train_idxs_{:.2f}_{}.npy'.format(f1_score, fold)), train_idxs_tmp)
            print('*' * 64)
            print('model saved: f1: {}\tacc: {}'.format(max_f1, max_acc))
            print('*' * 64)

    return total_loss

def get_param_group(model):
    nd_list = []
    param_list = []
    for name, param in model.named_parameters():
        if 'ln' in name:
            nd_list.append(param)
        else:
            param_list.append(param)
    return [{'params': param_list, 'weight_decay': 1e-5}, {'params': nd_list, 'weight_decay': 0}]

# %%
## Run this if the random indices do not give trainable model for fusenet.

# prefix = os.path.abspath(os.path.join(os.getcwd(), ".."))
# text_features = np.load(os.path.join(prefix, 'Features/TextWhole/whole_samples_clf_avg.npz'))['arr_0']
# text_targets = np.load(os.path.join(prefix, 'Features/TextWhole/whole_labels_clf_avg.npz'))['arr_0']
# text_dep_idxs_tmp = np.where(text_targets == 1)[0]
# text_non_idxs = np.where(text_targets == 0)[0]

# kf = KFold(n_splits=3, shuffle=True)
# fold = 1
# for train_idxs_tmp, test_idxs_tmp in kf.split(text_features):
#     ## Code to save the .npy files.
#     np.save(os.path.join(prefix, 'Features/TextWhole/train_idxs_{}.npy'.format(fold)), train_idxs_tmp)
#     np.save(os.path.join(prefix, 'Features/TextWhole/test_idxs_{}.npy'.format(fold)), test_idxs_tmp)
#     fold += 1

# %%
train_idxs_tmps = [np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_1.npy'), allow_pickle=True),
np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_2.npy'), allow_pickle=True),
np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_3.npy'), allow_pickle=True)]

# %%
for idx_idx, train_idxs_tmp in enumerate(train_idxs_tmps):
    fold = idx_idx + 1
    test_idxs_tmp = list(set(list(audio_dep_idxs_tmp)+list(audio_non_idxs)) - set(train_idxs_tmp))
    train_idxs, test_idxs = [], []
    resample_idxs = [0,1,2,3,4,5]
    
    # depression data augmentation
    for idx in train_idxs_tmp:
        if idx in audio_dep_idxs_tmp:
            feat = audio_features[idx]
            count = 0
            for i in itertools.permutations(feat, feat.shape[0]):
                if count in resample_idxs:
                    audio_features = np.vstack((audio_features, np.expand_dims(list(i), 0)))
                    audio_targets = np.hstack((audio_targets, 1))
                    train_idxs.append(len(audio_features)-1)
                count += 1
        else:
            train_idxs.append(idx)

    for idx in test_idxs_tmp:
        if idx in audio_dep_idxs_tmp:
            feat = audio_features[idx]
            count = 0
            # resample_idxs = random.sample(range(6), 4)
            resample_idxs = [0,1,4,5]
            for i in itertools.permutations(feat, feat.shape[0]):
                if count in resample_idxs:
                    audio_features = np.vstack((audio_features, np.expand_dims(list(i), 0)))
                    audio_targets = np.hstack((audio_targets, 1))
                    test_idxs.append(len(audio_features)-1)
                count += 1
        else:
            test_idxs.append(idx)

    model = AudioBiLSTM(config)

    if config['cuda']:
        model = model.cuda()

    param_group = get_param_group(model)
    optimizer = optim.AdamW(param_group, lr=config['learning_rate'])
    criterion = nn.CrossEntropyLoss()
    max_f1 = -1
    max_acc = -1
    max_rec = -1
    max_prec = -1
    train_acc = -1

    for ep in range(1, config['epochs']):
        train(ep, train_idxs)
        tloss = evaluate(model, test_idxs, fold, train_idxs_tmp, train_idxs)
    fold += 1
# Out:
# Train Epoch:  2	 Learning rate: 0.0000	Loss: 18.048500	 Accuracy: 107/208 (51%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch:  3	 Learning rate: 0.0000	Loss: 18.028795	 Accuracy: 94/208 (45%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch:  4	 Learning rate: 0.0000	Loss: 18.010088	 Accuracy: 109/208 (52%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch:  5	 Learning rate: 0.0000	Loss: 17.973298	 Accuracy: 112/208 (54%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch:  6	 Learning rate: 0.0000	Loss: 17.941164	 Accuracy: 119/208 (57%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch:  7	 Learning rate: 0.0000	Loss: 17.954516	 Accuracy: 117/208 (56%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch:  8	 Learning rate: 0.0000	Loss: 17.965038	 Accuracy: 123/208 (59%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch:  9	 Learning rate: 0.0000	Loss: 17.993291	 Accuracy: 108/208 (52%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 10	 Learning rate: 0.0000	Loss: 17.918752	 Accuracy: 121/208 (58%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 11	 Learning rate: 0.0000	Loss: 17.973540	 Accuracy: 104/208 (50%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 12	 Learning rate: 0.0000	Loss: 17.943973	 Accuracy: 116/208 (56%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 13	 Learning rate: 0.0000	Loss: 17.912282	 Accuracy: 128/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 14	 Learning rate: 0.0000	Loss: 17.922868	 Accuracy: 120/208 (58%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 15	 Learning rate: 0.0000	Loss: 17.871142	 Accuracy: 126/208 (61%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 16	 Learning rate: 0.0000	Loss: 17.951526	 Accuracy: 115/208 (55%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 17	 Learning rate: 0.0000	Loss: 17.900140	 Accuracy: 122/208 (59%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 18	 Learning rate: 0.0000	Loss: 17.928195	 Accuracy: 122/208 (59%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 19	 Learning rate: 0.0000	Loss: 17.886897	 Accuracy: 119/208 (57%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 20	 Learning rate: 0.0000	Loss: 17.861176	 Accuracy: 126/208 (61%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 21	 Learning rate: 0.0000	Loss: 17.869641	 Accuracy: 122/208 (59%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 22	 Learning rate: 0.0000	Loss: 17.813690	 Accuracy: 133/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 23	 Learning rate: 0.0000	Loss: 17.874862	 Accuracy: 122/208 (59%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 24	 Learning rate: 0.0000	Loss: 17.848326	 Accuracy: 126/208 (61%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 25	 Learning rate: 0.0000	Loss: 17.862080	 Accuracy: 124/208 (60%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 26	 Learning rate: 0.0000	Loss: 17.848908	 Accuracy: 132/208 (63%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 27	 Learning rate: 0.0000	Loss: 17.821070	 Accuracy: 128/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 28	 Learning rate: 0.0000	Loss: 17.795465	 Accuracy: 133/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 29	 Learning rate: 0.0000	Loss: 17.810428	 Accuracy: 131/208 (63%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 30	 Learning rate: 0.0000	Loss: 17.743254	 Accuracy: 135/208 (65%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 31	 Learning rate: 0.0000	Loss: 17.763662	 Accuracy: 139/208 (67%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 32	 Learning rate: 0.0000	Loss: 17.797373	 Accuracy: 130/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 33	 Learning rate: 0.0000	Loss: 17.734041	 Accuracy: 136/208 (65%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 34	 Learning rate: 0.0000	Loss: 17.723714	 Accuracy: 133/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 35	 Learning rate: 0.0000	Loss: 17.841093	 Accuracy: 126/208 (61%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 36	 Learning rate: 0.0000	Loss: 17.729651	 Accuracy: 121/208 (58%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 37	 Learning rate: 0.0000	Loss: 17.766488	 Accuracy: 134/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 38	 Learning rate: 0.0000	Loss: 17.655718	 Accuracy: 134/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 39	 Learning rate: 0.0000	Loss: 17.709628	 Accuracy: 126/208 (61%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 40	 Learning rate: 0.0000	Loss: 17.696449	 Accuracy: 134/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 41	 Learning rate: 0.0000	Loss: 17.685313	 Accuracy: 129/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 42	 Learning rate: 0.0000	Loss: 17.682498	 Accuracy: 132/208 (63%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 43	 Learning rate: 0.0000	Loss: 17.616079	 Accuracy: 137/208 (66%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 44	 Learning rate: 0.0000	Loss: 17.674640	 Accuracy: 128/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 45	 Learning rate: 0.0000	Loss: 17.726002	 Accuracy: 130/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 46	 Learning rate: 0.0000	Loss: 17.645932	 Accuracy: 132/208 (63%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 47	 Learning rate: 0.0000	Loss: 17.605630	 Accuracy: 130/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 48	 Learning rate: 0.0000	Loss: 17.589132	 Accuracy: 127/208 (61%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 49	 Learning rate: 0.0000	Loss: 17.605321	 Accuracy: 131/208 (63%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 50	 Learning rate: 0.0000	Loss: 17.611266	 Accuracy: 126/208 (61%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 51	 Learning rate: 0.0000	Loss: 17.588265	 Accuracy: 132/208 (63%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 52	 Learning rate: 0.0000	Loss: 17.561010	 Accuracy: 126/208 (61%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 53	 Learning rate: 0.0000	Loss: 17.515797	 Accuracy: 133/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 54	 Learning rate: 0.0000	Loss: 17.528304	 Accuracy: 134/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 55	 Learning rate: 0.0000	Loss: 17.499405	 Accuracy: 137/208 (66%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 56	 Learning rate: 0.0000	Loss: 17.483509	 Accuracy: 130/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 57	 Learning rate: 0.0000	Loss: 17.461179	 Accuracy: 137/208 (66%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 58	 Learning rate: 0.0000	Loss: 17.487152	 Accuracy: 137/208 (66%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 59	 Learning rate: 0.0000	Loss: 17.436958	 Accuracy: 135/208 (65%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 60	 Learning rate: 0.0000	Loss: 17.440446	 Accuracy: 136/208 (65%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 61	 Learning rate: 0.0000	Loss: 17.454985	 Accuracy: 130/208 (62%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 62	 Learning rate: 0.0000	Loss: 17.384592	 Accuracy: 136/208 (65%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 63	 Learning rate: 0.0000	Loss: 17.355469	 Accuracy: 133/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 64	 Learning rate: 0.0000	Loss: 17.320770	 Accuracy: 132/208 (63%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 65	 Learning rate: 0.0000	Loss: 17.340413	 Accuracy: 135/208 (65%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 66	 Learning rate: 0.0000	Loss: 17.277570	 Accuracy: 134/208 (64%)
#
# Confusion Matrix:
# [[40 44]
#  [ 0  0]]
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 67	 Learning rate: 0.0000	Loss: 17.348838	 Accuracy: 133/208 (64%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 68	 Learning rate: 0.0000	Loss: 17.246151	 Accuracy: 134/208 (64%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 69	 Learning rate: 0.0000	Loss: 17.253913	 Accuracy: 136/208 (65%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 70	 Learning rate: 0.0000	Loss: 17.177007	 Accuracy: 132/208 (63%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 71	 Learning rate: 0.0000	Loss: 17.187705	 Accuracy: 137/208 (66%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 72	 Learning rate: 0.0000	Loss: 17.194962	 Accuracy: 137/208 (66%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 73	 Learning rate: 0.0000	Loss: 17.110184	 Accuracy: 139/208 (67%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 74	 Learning rate: 0.0000	Loss: 17.123812	 Accuracy: 141/208 (68%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 75	 Learning rate: 0.0000	Loss: 17.071242	 Accuracy: 135/208 (65%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 76	 Learning rate: 0.0000	Loss: 17.049710	 Accuracy: 136/208 (65%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 77	 Learning rate: 0.0000	Loss: 16.969439	 Accuracy: 140/208 (67%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 78	 Learning rate: 0.0000	Loss: 16.973937	 Accuracy: 139/208 (67%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 79	 Learning rate: 0.0000	Loss: 16.965203	 Accuracy: 142/208 (68%)
#
# Confusion Matrix:
# [[40 43]
#  [ 0  1]]
# Accuracy: 0.4880952380952381
# Precision: 0.4819277108433735
# Recall: 1.0
# F1-Score: 0.6504065040650406
#
# =========================================================================================
# Train Epoch: 80	 Learning rate: 0.0000	Loss: 16.946605	 Accuracy: 139/208 (67%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 81	 Learning rate: 0.0000	Loss: 16.930957	 Accuracy: 136/208 (65%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 82	 Learning rate: 0.0000	Loss: 16.900897	 Accuracy: 138/208 (66%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 83	 Learning rate: 0.0000	Loss: 16.847675	 Accuracy: 137/208 (66%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 84	 Learning rate: 0.0000	Loss: 16.797030	 Accuracy: 145/208 (70%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 85	 Learning rate: 0.0000	Loss: 16.767305	 Accuracy: 140/208 (67%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 86	 Learning rate: 0.0000	Loss: 16.763760	 Accuracy: 140/208 (67%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 87	 Learning rate: 0.0000	Loss: 16.630275	 Accuracy: 143/208 (69%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 88	 Learning rate: 0.0000	Loss: 16.743306	 Accuracy: 151/208 (73%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 89	 Learning rate: 0.0000	Loss: 16.575344	 Accuracy: 143/208 (69%)
#
# Confusion Matrix:
# [[40 42]
#  [ 0  2]]
# Accuracy: 0.5
# Precision: 0.4878048780487805
# Recall: 1.0
# F1-Score: 0.6557377049180327
#
# =========================================================================================
# Train Epoch: 90	 Learning rate: 0.0000	Loss: 16.598290	 Accuracy: 137/208 (66%)
#
# Confusion Matrix:
# [[39 41]
#  [ 1  3]]
# Accuracy: 0.5
# Precision: 0.4875
# Recall: 0.975
# F1-Score: 0.65
#
# =========================================================================================
# Train Epoch: 91	 Learning rate: 0.0000	Loss: 16.606347	 Accuracy: 138/208 (66%)
#
# Confusion Matrix:
# [[39 41]
#  [ 1  3]]
# Accuracy: 0.5
# Precision: 0.4875
# Recall: 0.975
# F1-Score: 0.65
#
# =========================================================================================
# Train Epoch: 92	 Learning rate: 0.0000	Loss: 16.485771	 Accuracy: 141/208 (68%)
#
# Confusion Matrix:
# [[39 41]
#  [ 1  3]]
# Accuracy: 0.5
# Precision: 0.4875
# Recall: 0.975
# F1-Score: 0.65
#
# =========================================================================================
# Train Epoch: 93	 Learning rate: 0.0000	Loss: 16.497740	 Accuracy: 138/208 (66%)
#
# Confusion Matrix:
# [[39 41]
#  [ 1  3]]
# Accuracy: 0.5
# Precision: 0.4875
# Recall: 0.975
# F1-Score: 0.65
#
# =========================================================================================
# Train Epoch: 94	 Learning rate: 0.0000	Loss: 16.392818	 Accuracy: 145/208 (70%)
#
# Confusion Matrix:
# [[39 41]
#  [ 1  3]]
# Accuracy: 0.5
# Precision: 0.4875
# Recall: 0.975
# F1-Score: 0.65
#
# =========================================================================================
# Train Epoch: 95	 Learning rate: 0.0000	Loss: 16.335198	 Accuracy: 147/208 (71%)
#
# Confusion Matrix:
# [[37 41]
#  [ 3  3]]
# Accuracy: 0.47619047619047616
# Precision: 0.47435897435897434
# Recall: 0.925
# F1-Score: 0.6271186440677966
#
# =========================================================================================
# Train Epoch: 96	 Learning rate: 0.0000	Loss: 16.311604	 Accuracy: 149/208 (72%)
#
# Confusion Matrix:
# [[37 41]
#  [ 3  3]]
# Accuracy: 0.47619047619047616
# Precision: 0.47435897435897434
# Recall: 0.925
# F1-Score: 0.6271186440677966
#
# =========================================================================================
# Train Epoch: 97	 Learning rate: 0.0000	Loss: 16.301915	 Accuracy: 145/208 (70%)
#
# Confusion Matrix:
# [[37 41]
#  [ 3  3]]
# Accuracy: 0.47619047619047616
# Precision: 0.47435897435897434
# Recall: 0.925
# F1-Score: 0.6271186440677966
#
# =========================================================================================
# Train Epoch: 98	 Learning rate: 0.0000	Loss: 16.170896	 Accuracy: 144/208 (69%)
#
# Confusion Matrix:
# [[37 41]
#  [ 3  3]]
# Accuracy: 0.47619047619047616
# Precision: 0.47435897435897434
# Recall: 0.925
# F1-Score: 0.6271186440677966
#
# =========================================================================================
# Train Epoch: 99	 Learning rate: 0.0000	Loss: 16.131733	 Accuracy: 149/208 (72%)
#
# Confusion Matrix:
# [[37 41]
#  [ 3  3]]
# Accuracy: 0.47619047619047616
# Precision: 0.47435897435897434
# Recall: 0.925
# F1-Score: 0.6271186440677966
#
# =========================================================================================
# Train Epoch: 100	 Learning rate: 0.0000	Loss: 16.100313	 Accuracy: 149/208 (72%)
#
# Confusion Matrix:
# [[37 41]
#  [ 3  3]]
# Accuracy: 0.47619047619047616
# Precision: 0.47435897435897434
# Recall: 0.925
# F1-Score: 0.6271186440677966
#
# =========================================================================================
# Train Epoch: 101	 Learning rate: 0.0000	Loss: 16.083425	 Accuracy: 144/208 (69%)
#
# Confusion Matrix:
# [[36 41]
#  [ 4  3]]
# Accuracy: 0.4642857142857143
# Precision: 0.4675324675324675
# Recall: 0.9
# F1-Score: 0.6153846153846153
#
# =========================================================================================
# Train Epoch: 102	 Learning rate: 0.0000	Loss: 16.039802	 Accuracy: 148/208 (71%)
#
# Confusion Matrix:
# [[36 41]
#  [ 4  3]]
# Accuracy: 0.4642857142857143
# Precision: 0.4675324675324675
# Recall: 0.9
# F1-Score: 0.6153846153846153
#
# =========================================================================================
# Train Epoch: 103	 Learning rate: 0.0000	Loss: 15.886642	 Accuracy: 144/208 (69%)
#
# Confusion Matrix:
# [[36 41]
#  [ 4  3]]
# Accuracy: 0.4642857142857143
# Precision: 0.4675324675324675
# Recall: 0.9
# F1-Score: 0.6153846153846153
#
# =========================================================================================
# Train Epoch: 104	 Learning rate: 0.0000	Loss: 15.856925	 Accuracy: 153/208 (74%)
#
# Confusion Matrix:
# [[36 40]
#  [ 4  4]]
# Accuracy: 0.47619047619047616
# Precision: 0.47368421052631576
# Recall: 0.9
# F1-Score: 0.6206896551724138
#
# =========================================================================================
# Train Epoch: 105	 Learning rate: 0.0000	Loss: 15.845592	 Accuracy: 151/208 (73%)
#
# Confusion Matrix:
# [[36 40]
#  [ 4  4]]
# Accuracy: 0.47619047619047616
# Precision: 0.47368421052631576
# Recall: 0.9
# F1-Score: 0.6206896551724138
#
# =========================================================================================
# Train Epoch: 106	 Learning rate: 0.0000	Loss: 15.794068	 Accuracy: 148/208 (71%)
#
# Confusion Matrix:
# [[36 40]
#  [ 4  4]]
# Accuracy: 0.47619047619047616
# Precision: 0.47368421052631576
# Recall: 0.9
# F1-Score: 0.6206896551724138
#
# =========================================================================================
# Train Epoch: 107	 Learning rate: 0.0000	Loss: 15.656361	 Accuracy: 149/208 (72%)
#
# Confusion Matrix:
# [[35 40]
#  [ 5  4]]
# Accuracy: 0.4642857142857143
# Precision: 0.4666666666666667
# Recall: 0.875
# F1-Score: 0.608695652173913
#
# =========================================================================================
# Train Epoch: 108	 Learning rate: 0.0000	Loss: 15.652660	 Accuracy: 150/208 (72%)
#
# Confusion Matrix:
# [[35 39]
#  [ 5  5]]
# Accuracy: 0.47619047619047616
# Precision: 0.47297297297297297
# Recall: 0.875
# F1-Score: 0.6140350877192983
#
# =========================================================================================
# Train Epoch: 109	 Learning rate: 0.0000	Loss: 15.471326	 Accuracy: 160/208 (77%)
#
# Confusion Matrix:
# [[35 39]
#  [ 5  5]]
# Accuracy: 0.47619047619047616
# Precision: 0.47297297297297297
# Recall: 0.875
# F1-Score: 0.6140350877192983
#
# =========================================================================================
# Train Epoch: 110	 Learning rate: 0.0000	Loss: 15.537840	 Accuracy: 155/208 (75%)
#
# Confusion Matrix:
# [[34 39]
#  [ 6  5]]
# Accuracy: 0.4642857142857143
# Precision: 0.4657534246575342
# Recall: 0.85
# F1-Score: 0.6017699115044248
#
# =========================================================================================
# Train Epoch: 111	 Learning rate: 0.0000	Loss: 15.476021	 Accuracy: 156/208 (75%)
#
# Confusion Matrix:
# [[34 37]
#  [ 6  7]]
# Accuracy: 0.4880952380952381
# Precision: 0.4788732394366197
# Recall: 0.85
# F1-Score: 0.6126126126126126
#
# =========================================================================================
# Train Epoch: 112	 Learning rate: 0.0000	Loss: 15.357931	 Accuracy: 154/208 (74%)
#
# Confusion Matrix:
# [[34 37]
#  [ 6  7]]
# Accuracy: 0.4880952380952381
# Precision: 0.4788732394366197
# Recall: 0.85
# F1-Score: 0.6126126126126126
#
# =========================================================================================
# Train Epoch: 113	 Learning rate: 0.0000	Loss: 15.359769	 Accuracy: 157/208 (75%)
#
# Confusion Matrix:
# [[33 37]
#  [ 7  7]]
# Accuracy: 0.47619047619047616
# Precision: 0.4714285714285714
# Recall: 0.825
# F1-Score: 0.6000000000000001
#
# =========================================================================================
# Train Epoch: 114	 Learning rate: 0.0000	Loss: 15.164683	 Accuracy: 156/208 (75%)
#
# Confusion Matrix:
# [[33 36]
#  [ 7  8]]
# Accuracy: 0.4880952380952381
# Precision: 0.4782608695652174
# Recall: 0.825
# F1-Score: 0.6055045871559632
#
# =========================================================================================
# Train Epoch: 115	 Learning rate: 0.0000	Loss: 15.016688	 Accuracy: 155/208 (75%)
#
# Confusion Matrix:
# [[33 36]
#  [ 7  8]]
# Accuracy: 0.4880952380952381
# Precision: 0.4782608695652174
# Recall: 0.825
# F1-Score: 0.6055045871559632
#
# =========================================================================================
# Train Epoch: 116	 Learning rate: 0.0000	Loss: 15.055430	 Accuracy: 160/208 (77%)
#
# Confusion Matrix:
# [[33 36]
#  [ 7  8]]
# Accuracy: 0.4880952380952381
# Precision: 0.4782608695652174
# Recall: 0.825
# F1-Score: 0.6055045871559632
#
# =========================================================================================
# Train Epoch: 117	 Learning rate: 0.0000	Loss: 14.925445	 Accuracy: 162/208 (78%)
#
# Confusion Matrix:
# [[33 36]
#  [ 7  8]]
# Accuracy: 0.4880952380952381
# Precision: 0.4782608695652174
# Recall: 0.825
# F1-Score: 0.6055045871559632
#
# =========================================================================================
# Train Epoch: 118	 Learning rate: 0.0000	Loss: 14.961964	 Accuracy: 154/208 (74%)
#
# Confusion Matrix:
# [[33 36]
#  [ 7  8]]
# Accuracy: 0.4880952380952381
# Precision: 0.4782608695652174
# Recall: 0.825
# F1-Score: 0.6055045871559632
#
# =========================================================================================
# Train Epoch: 119	 Learning rate: 0.0000	Loss: 14.856763	 Accuracy: 162/208 (78%)
#
# Confusion Matrix:
# [[33 36]
#  [ 7  8]]
# Accuracy: 0.4880952380952381
# Precision: 0.4782608695652174
# Recall: 0.825
# F1-Score: 0.6055045871559632
#
# =========================================================================================
# Train Epoch: 120	 Learning rate: 0.0000	Loss: 14.745509	 Accuracy: 164/208 (79%)
#
# Confusion Matrix:
# [[33 36]
#  [ 7  8]]
# Accuracy: 0.4880952380952381
# Precision: 0.4782608695652174
# Recall: 0.825
# F1-Score: 0.6055045871559632
#
# =========================================================================================
# Train Epoch: 121	 Learning rate: 0.0000	Loss: 14.675778	 Accuracy: 169/208 (81%)
#
# Confusion Matrix:
# [[33 35]
#  [ 7  9]]
# Accuracy: 0.5
# Precision: 0.4852941176470588
# Recall: 0.825
# F1-Score: 0.611111111111111
#
# =========================================================================================
# Train Epoch: 122	 Learning rate: 0.0000	Loss: 14.735010	 Accuracy: 165/208 (79%)
#
# Confusion Matrix:
# [[33 34]
#  [ 7 10]]
# Accuracy: 0.5119047619047619
# Precision: 0.4925373134328358
# Recall: 0.825
# F1-Score: 0.6168224299065419
#
# =========================================================================================
# Train Epoch: 123	 Learning rate: 0.0000	Loss: 14.520731	 Accuracy: 166/208 (80%)
#
# Confusion Matrix:
# [[33 34]
#  [ 7 10]]
# Accuracy: 0.5119047619047619
# Precision: 0.4925373134328358
# Recall: 0.825
# F1-Score: 0.6168224299065419
#
# =========================================================================================
# Train Epoch: 124	 Learning rate: 0.0000	Loss: 14.427539	 Accuracy: 166/208 (80%)
#
# Confusion Matrix:
# [[31 34]
#  [ 9 10]]
# Accuracy: 0.4880952380952381
# Precision: 0.47692307692307695
# Recall: 0.775
# F1-Score: 0.5904761904761905
#
# =========================================================================================
# Train Epoch: 125	 Learning rate: 0.0000	Loss: 14.413210	 Accuracy: 161/208 (77%)
#
# Confusion Matrix:
# [[31 34]
#  [ 9 10]]
# Accuracy: 0.4880952380952381
# Precision: 0.47692307692307695
# Recall: 0.775
# F1-Score: 0.5904761904761905
#
# =========================================================================================
# Train Epoch: 126	 Learning rate: 0.0000	Loss: 14.264838	 Accuracy: 174/208 (84%)
#
# Confusion Matrix:
# [[31 34]
#  [ 9 10]]
# Accuracy: 0.4880952380952381
# Precision: 0.47692307692307695
# Recall: 0.775
# F1-Score: 0.5904761904761905
#
# =========================================================================================
# Train Epoch: 127	 Learning rate: 0.0000	Loss: 14.232504	 Accuracy: 162/208 (78%)
#
# Confusion Matrix:
# [[31 34]
#  [ 9 10]]
# Accuracy: 0.4880952380952381
# Precision: 0.47692307692307695
# Recall: 0.775
# F1-Score: 0.5904761904761905
#
# =========================================================================================
# Train Epoch: 128	 Learning rate: 0.0000	Loss: 14.202071	 Accuracy: 165/208 (79%)
#
# Confusion Matrix:
# [[31 34]
#  [ 9 10]]
# Accuracy: 0.4880952380952381
# Precision: 0.47692307692307695
# Recall: 0.775
# F1-Score: 0.5904761904761905
#
# =========================================================================================
# Train Epoch: 129	 Learning rate: 0.0000	Loss: 14.097490	 Accuracy: 167/208 (80%)
#
# Confusion Matrix:
# [[31 34]
#  [ 9 10]]
# Accuracy: 0.4880952380952381
# Precision: 0.47692307692307695
# Recall: 0.775
# F1-Score: 0.5904761904761905
#
# =========================================================================================
# Train Epoch: 130	 Learning rate: 0.0000	Loss: 14.087618	 Accuracy: 167/208 (80%)
#
# Confusion Matrix:
# [[31 33]
#  [ 9 11]]
# Accuracy: 0.5
# Precision: 0.484375
# Recall: 0.775
# F1-Score: 0.5961538461538463
#
# =========================================================================================
# Train Epoch: 131	 Learning rate: 0.0000	Loss: 13.990182	 Accuracy: 174/208 (84%)
#
# Confusion Matrix:
# [[31 33]
#  [ 9 11]]
# Accuracy: 0.5
# Precision: 0.484375
# Recall: 0.775
# F1-Score: 0.5961538461538463
#
# =========================================================================================
# Train Epoch: 132	 Learning rate: 0.0000	Loss: 13.887267	 Accuracy: 177/208 (85%)
#
# Confusion Matrix:
# [[31 33]
#  [ 9 11]]
# Accuracy: 0.5
# Precision: 0.484375
# Recall: 0.775
# F1-Score: 0.5961538461538463
#
# =========================================================================================
# Train Epoch: 133	 Learning rate: 0.0000	Loss: 13.879180	 Accuracy: 171/208 (82%)
#
# Confusion Matrix:
# [[31 33]
#  [ 9 11]]
# Accuracy: 0.5
# Precision: 0.484375
# Recall: 0.775
# F1-Score: 0.5961538461538463
#
# =========================================================================================
# Train Epoch: 134	 Learning rate: 0.0000	Loss: 13.734600	 Accuracy: 171/208 (82%)
#
# Confusion Matrix:
# [[31 33]
#  [ 9 11]]
# Accuracy: 0.5
# Precision: 0.484375
# Recall: 0.775
# F1-Score: 0.5961538461538463
#
# =========================================================================================
# Train Epoch: 135	 Learning rate: 0.0000	Loss: 13.704862	 Accuracy: 175/208 (84%)
#
# Confusion Matrix:
# [[31 32]
#  [ 9 12]]
# Accuracy: 0.5119047619047619
# Precision: 0.49206349206349204
# Recall: 0.775
# F1-Score: 0.6019417475728155
#
# =========================================================================================
# Train Epoch: 136	 Learning rate: 0.0000	Loss: 13.771930	 Accuracy: 171/208 (82%)
#
# Confusion Matrix:
# [[31 32]
#  [ 9 12]]
# Accuracy: 0.5119047619047619
# Precision: 0.49206349206349204
# Recall: 0.775
# F1-Score: 0.6019417475728155
#
# =========================================================================================
# Train Epoch: 137	 Learning rate: 0.0000	Loss: 13.617023	 Accuracy: 173/208 (83%)
#
# Confusion Matrix:
# [[30 32]
#  [10 12]]
# Accuracy: 0.5
# Precision: 0.4838709677419355
# Recall: 0.75
# F1-Score: 0.5882352941176471
#
# =========================================================================================
# Train Epoch: 138	 Learning rate: 0.0000	Loss: 13.513515	 Accuracy: 174/208 (84%)
#
# Confusion Matrix:
# [[30 32]
#  [10 12]]
# Accuracy: 0.5
# Precision: 0.4838709677419355
# Recall: 0.75
# F1-Score: 0.5882352941176471
#
# =========================================================================================
# Train Epoch: 139	 Learning rate: 0.0000	Loss: 13.595775	 Accuracy: 175/208 (84%)
#
# Confusion Matrix:
# [[30 32]
#  [10 12]]
# Accuracy: 0.5
# Precision: 0.4838709677419355
# Recall: 0.75
# F1-Score: 0.5882352941176471
#
# =========================================================================================
# Train Epoch: 140	 Learning rate: 0.0000	Loss: 13.446546	 Accuracy: 177/208 (85%)
#
# Confusion Matrix:
# [[30 31]
#  [10 13]]
# Accuracy: 0.5119047619047619
# Precision: 0.4918032786885246
# Recall: 0.75
# F1-Score: 0.5940594059405939
#
# =========================================================================================
# Train Epoch: 141	 Learning rate: 0.0000	Loss: 13.401829	 Accuracy: 176/208 (85%)
#
# Confusion Matrix:
# [[29 30]
#  [11 14]]
# Accuracy: 0.5119047619047619
# Precision: 0.4915254237288136
# Recall: 0.725
# F1-Score: 0.5858585858585859
#
# =========================================================================================
# Train Epoch: 142	 Learning rate: 0.0000	Loss: 13.137048	 Accuracy: 184/208 (88%)
#
# Confusion Matrix:
# [[29 30]
#  [11 14]]
# Accuracy: 0.5119047619047619
# Precision: 0.4915254237288136
# Recall: 0.725
# F1-Score: 0.5858585858585859
#
# =========================================================================================
# Train Epoch: 143	 Learning rate: 0.0000	Loss: 13.147459	 Accuracy: 181/208 (87%)
#
# Confusion Matrix:
# [[29 30]
#  [11 14]]
# Accuracy: 0.5119047619047619
# Precision: 0.4915254237288136
# Recall: 0.725
# F1-Score: 0.5858585858585859
#
# =========================================================================================
# Train Epoch: 144	 Learning rate: 0.0000	Loss: 12.996395	 Accuracy: 184/208 (88%)
#
# Confusion Matrix:
# [[29 29]
#  [11 15]]
# Accuracy: 0.5238095238095238
# Precision: 0.5
# Recall: 0.725
# F1-Score: 0.5918367346938775
#
# =========================================================================================
# Train Epoch: 145	 Learning rate: 0.0000	Loss: 13.116806	 Accuracy: 180/208 (87%)
#
# Confusion Matrix:
# [[29 29]
#  [11 15]]
# Accuracy: 0.5238095238095238
# Precision: 0.5
# Recall: 0.725
# F1-Score: 0.5918367346938775
#
# =========================================================================================
# Train Epoch: 146	 Learning rate: 0.0000	Loss: 12.923697	 Accuracy: 186/208 (89%)
#
# Confusion Matrix:
# [[28 29]
#  [12 15]]
# Accuracy: 0.5119047619047619
# Precision: 0.49122807017543857
# Recall: 0.7
# F1-Score: 0.5773195876288659
#
# =========================================================================================
# Train Epoch: 147	 Learning rate: 0.0000	Loss: 13.039253	 Accuracy: 181/208 (87%)
#
# Confusion Matrix:
# [[28 28]
#  [12 16]]
# Accuracy: 0.5238095238095238
# Precision: 0.5
# Recall: 0.7
# F1-Score: 0.5833333333333334
#
# =========================================================================================
# Train Epoch: 148	 Learning rate: 0.0000	Loss: 12.835046	 Accuracy: 187/208 (90%)
#
# Confusion Matrix:
# [[27 27]
#  [13 17]]
# Accuracy: 0.5238095238095238
# Precision: 0.5
# Recall: 0.675
# F1-Score: 0.574468085106383
#
# =========================================================================================
# Train Epoch: 149	 Learning rate: 0.0000	Loss: 12.793165	 Accuracy: 187/208 (90%)
#
# Confusion Matrix:
# [[26 26]
#  [14 18]]
# Accuracy: 0.5238095238095238
# Precision: 0.5
# Recall: 0.65
# F1-Score: 0.5652173913043479
#
# =========================================================================================
# Train Epoch: 150	 Learning rate: 0.0000	Loss: 12.771206	 Accuracy: 183/208 (88%)
#
# Confusion Matrix:
# [[25 26]
#  [15 18]]
# Accuracy: 0.5119047619047619
# Precision: 0.49019607843137253
# Recall: 0.625
# F1-Score: 0.5494505494505494
#
# =========================================================================================
# Train Epoch: 151	 Learning rate: 0.0000	Loss: 12.774094	 Accuracy: 187/208 (90%)
#
# Confusion Matrix:
# [[25 26]
#  [15 18]]
# Accuracy: 0.5119047619047619
# Precision: 0.49019607843137253
# Recall: 0.625
# F1-Score: 0.5494505494505494
#
# =========================================================================================
# Train Epoch: 152	 Learning rate: 0.0000	Loss: 12.518960	 Accuracy: 193/208 (93%)
#
# Confusion Matrix:
# [[25 26]
#  [15 18]]
# Accuracy: 0.5119047619047619
# Precision: 0.49019607843137253
# Recall: 0.625
# F1-Score: 0.5494505494505494
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Audio/BiLSTM_gru_vlad256_256_0.55_1.pt
# ****************************************************************
# model saved: f1: 0.5494505494505494	acc: 0.5119047619047619
# ****************************************************************
# Train Epoch: 153	 Learning rate: 0.0000	Loss: 12.544050	 Accuracy: 191/208 (92%)
#
# Confusion Matrix:
# [[25 26]
#  [15 18]]
# Accuracy: 0.5119047619047619
# Precision: 0.49019607843137253
# Recall: 0.625
# F1-Score: 0.5494505494505494
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Audio/BiLSTM_gru_vlad256_256_0.55_1.pt
# ****************************************************************
# model saved: f1: 0.5494505494505494	acc: 0.5119047619047619
# ****************************************************************
# Train Epoch: 154	 Learning rate: 0.0000	Loss: 12.448902	 Accuracy: 194/208 (93%)
#
# Confusion Matrix:
# [[25 26]
#  [15 18]]
# Accuracy: 0.5119047619047619
# Precision: 0.49019607843137253
# Recall: 0.625
# F1-Score: 0.5494505494505494
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Audio/BiLSTM_gru_vlad256_256_0.55_1.pt
# ****************************************************************
# ...
#
# Confusion Matrix:
# [[30 39]
#  [ 6  6]]
# Accuracy: 0.4444444444444444
# Precision: 0.43478260869565216
# Recall: 0.8333333333333334
# F1-Score: 0.5714285714285714
#
# =========================================================================================
# Train Epoch: 122	 Learning rate: 0.0000	Loss: 15.750711	 Accuracy: 161/213 (76%)
#
# Confusion Matrix:
# [[30 39]
#  [ 6  6]]
# Accuracy: 0.4444444444444444
# Precision: 0.43478260869565216
# Recall: 0.8333333333333334
# F1-Score: 0.5714285714285714
#
# =========================================================================================
# Train Epoch: 123	 Learning rate: 0.0000	Loss: 15.701106	 Accuracy: 161/213 (76%)
#
# Confusion Matrix:
# [[30 39]
#  [ 6  6]]
# Accuracy: 0.4444444444444444
# Precision: 0.43478260869565216
# Recall: 0.8333333333333334
# F1-Score: 0.5714285714285714
#
# =========================================================================================
# Train Epoch: 124	 Learning rate: 0.0000	Loss: 15.557377	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[29 38]
#  [ 7  7]]
# Accuracy: 0.4444444444444444
# Precision: 0.43283582089552236
# Recall: 0.8055555555555556
# F1-Score: 0.5631067961165048
#
# =========================================================================================
# Train Epoch: 125	 Learning rate: 0.0000	Loss: 15.452038	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[29 38]
#  [ 7  7]]
# Accuracy: 0.4444444444444444
# Precision: 0.43283582089552236
# Recall: 0.8055555555555556
# F1-Score: 0.5631067961165048
#
# =========================================================================================
# Train Epoch: 126	 Learning rate: 0.0000	Loss: 15.401541	 Accuracy: 167/213 (78%)
#
# Confusion Matrix:
# [[29 36]
#  [ 7  9]]
# Accuracy: 0.4691358024691358
# Precision: 0.4461538461538462
# Recall: 0.8055555555555556
# F1-Score: 0.5742574257425743
#
# =========================================================================================
# Train Epoch: 127	 Learning rate: 0.0000	Loss: 15.299359	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[28 36]
#  [ 8  9]]
# Accuracy: 0.4567901234567901
# Precision: 0.4375
# Recall: 0.7777777777777778
# F1-Score: 0.56
#
# =========================================================================================
# Train Epoch: 128	 Learning rate: 0.0000	Loss: 15.141371	 Accuracy: 171/213 (80%)
#
# Confusion Matrix:
# [[28 36]
#  [ 8  9]]
# Accuracy: 0.4567901234567901
# Precision: 0.4375
# Recall: 0.7777777777777778
# F1-Score: 0.56
#
# =========================================================================================
# Train Epoch: 129	 Learning rate: 0.0000	Loss: 15.197904	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[28 36]
#  [ 8  9]]
# Accuracy: 0.4567901234567901
# Precision: 0.4375
# Recall: 0.7777777777777778
# F1-Score: 0.56
#
# =========================================================================================
# Train Epoch: 130	 Learning rate: 0.0000	Loss: 15.230219	 Accuracy: 171/213 (80%)
#
# Confusion Matrix:
# [[28 36]
#  [ 8  9]]
# Accuracy: 0.4567901234567901
# Precision: 0.4375
# Recall: 0.7777777777777778
# F1-Score: 0.56
#
# =========================================================================================
# Train Epoch: 131	 Learning rate: 0.0000	Loss: 15.053637	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[28 36]
#  [ 8  9]]
# Accuracy: 0.4567901234567901
# Precision: 0.4375
# Recall: 0.7777777777777778
# F1-Score: 0.56
#
# =========================================================================================
# Train Epoch: 132	 Learning rate: 0.0000	Loss: 14.981147	 Accuracy: 167/213 (78%)
#
# Confusion Matrix:
# [[27 36]
#  [ 9  9]]
# Accuracy: 0.4444444444444444
# Precision: 0.42857142857142855
# Recall: 0.75
# F1-Score: 0.5454545454545454
#
# =========================================================================================
# Train Epoch: 133	 Learning rate: 0.0000	Loss: 15.014984	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[27 36]
#  [ 9  9]]
# Accuracy: 0.4444444444444444
# Precision: 0.42857142857142855
# Recall: 0.75
# F1-Score: 0.5454545454545454
#
# =========================================================================================
# Train Epoch: 134	 Learning rate: 0.0000	Loss: 14.854641	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[27 36]
#  [ 9  9]]
# Accuracy: 0.4444444444444444
# Precision: 0.42857142857142855
# Recall: 0.75
# F1-Score: 0.5454545454545454
#
# =========================================================================================
# Train Epoch: 135	 Learning rate: 0.0000	Loss: 14.819425	 Accuracy: 169/213 (79%)
#
# Confusion Matrix:
# [[27 35]
#  [ 9 10]]
# Accuracy: 0.4567901234567901
# Precision: 0.43548387096774194
# Recall: 0.75
# F1-Score: 0.5510204081632653
#
# =========================================================================================
# Train Epoch: 136	 Learning rate: 0.0000	Loss: 14.671783	 Accuracy: 175/213 (82%)
#
# Confusion Matrix:
# [[27 35]
#  [ 9 10]]
# Accuracy: 0.4567901234567901
# Precision: 0.43548387096774194
# Recall: 0.75
# F1-Score: 0.5510204081632653
#
# =========================================================================================
# Train Epoch: 137	 Learning rate: 0.0000	Loss: 14.703429	 Accuracy: 165/213 (77%)
#
# Confusion Matrix:
# [[27 35]
#  [ 9 10]]
# Accuracy: 0.4567901234567901
# Precision: 0.43548387096774194
# Recall: 0.75
# F1-Score: 0.5510204081632653
#
# =========================================================================================
# Train Epoch: 138	 Learning rate: 0.0000	Loss: 14.623465	 Accuracy: 166/213 (78%)
#
# Confusion Matrix:
# [[27 35]
#  [ 9 10]]
# Accuracy: 0.4567901234567901
# Precision: 0.43548387096774194
# Recall: 0.75
# F1-Score: 0.5510204081632653
#
# =========================================================================================
# Train Epoch: 139	 Learning rate: 0.0000	Loss: 14.471563	 Accuracy: 168/213 (79%)
#
# Confusion Matrix:
# [[27 35]
#  [ 9 10]]
# Accuracy: 0.4567901234567901
# Precision: 0.43548387096774194
# Recall: 0.75
# F1-Score: 0.5510204081632653
#
# =========================================================================================
# Train Epoch: 140	 Learning rate: 0.0000	Loss: 14.577574	 Accuracy: 171/213 (80%)
#
# Confusion Matrix:
# [[26 35]
#  [10 10]]
# Accuracy: 0.4444444444444444
# Precision: 0.4262295081967213
# Recall: 0.7222222222222222
# F1-Score: 0.5360824742268041
#
# =========================================================================================
# Train Epoch: 141	 Learning rate: 0.0000	Loss: 14.440789	 Accuracy: 173/213 (81%)
#
# Confusion Matrix:
# [[26 34]
#  [10 11]]
# Accuracy: 0.4567901234567901
# Precision: 0.43333333333333335
# Recall: 0.7222222222222222
# F1-Score: 0.5416666666666666
#
# =========================================================================================
# Train Epoch: 142	 Learning rate: 0.0000	Loss: 14.423502	 Accuracy: 170/213 (80%)
#
# Confusion Matrix:
# [[26 34]
#  [10 11]]
# Accuracy: 0.4567901234567901
# Precision: 0.43333333333333335
# Recall: 0.7222222222222222
# F1-Score: 0.5416666666666666
#
# =========================================================================================
# Train Epoch: 143	 Learning rate: 0.0000	Loss: 14.308689	 Accuracy: 171/213 (80%)
#
# Confusion Matrix:
# [[26 34]
#  [10 11]]
# Accuracy: 0.4567901234567901
# Precision: 0.43333333333333335
# Recall: 0.7222222222222222
# F1-Score: 0.5416666666666666
#
# =========================================================================================
# Train Epoch: 144	 Learning rate: 0.0000	Loss: 14.189780	 Accuracy: 174/213 (82%)
#
# Confusion Matrix:
# [[26 33]
#  [10 12]]
# Accuracy: 0.4691358024691358
# Precision: 0.4406779661016949
# Recall: 0.7222222222222222
# F1-Score: 0.5473684210526315
#
# =========================================================================================
# Train Epoch: 145	 Learning rate: 0.0000	Loss: 14.170897	 Accuracy: 172/213 (81%)
#
# Confusion Matrix:
# [[26 33]
#  [10 12]]
# Accuracy: 0.4691358024691358
# Precision: 0.4406779661016949
# Recall: 0.7222222222222222
# F1-Score: 0.5473684210526315
#
# =========================================================================================
# Train Epoch: 146	 Learning rate: 0.0000	Loss: 14.171798	 Accuracy: 176/213 (83%)
#
# Confusion Matrix:
# [[26 33]
#  [10 12]]
# Accuracy: 0.4691358024691358
# Precision: 0.4406779661016949
# Recall: 0.7222222222222222
# F1-Score: 0.5473684210526315
#
# =========================================================================================
# Train Epoch: 147	 Learning rate: 0.0000	Loss: 14.064343	 Accuracy: 175/213 (82%)
#
# Confusion Matrix:
# [[26 32]
#  [10 13]]
# Accuracy: 0.48148148148148145
# Precision: 0.4482758620689655
# Recall: 0.7222222222222222
# F1-Score: 0.5531914893617021
#
# =========================================================================================
# Train Epoch: 148	 Learning rate: 0.0000	Loss: 13.982585	 Accuracy: 184/213 (86%)
#
# Confusion Matrix:
# [[25 31]
#  [11 14]]
# Accuracy: 0.48148148148148145
# Precision: 0.44642857142857145
# Recall: 0.6944444444444444
# F1-Score: 0.5434782608695653
#
# =========================================================================================
# Train Epoch: 149	 Learning rate: 0.0000	Loss: 13.958937	 Accuracy: 176/213 (83%)
#
# Confusion Matrix:
# [[25 31]
#  [11 14]]
# Accuracy: 0.48148148148148145
# Precision: 0.44642857142857145
# Recall: 0.6944444444444444
# F1-Score: 0.5434782608695653
#
# =========================================================================================
# Train Epoch: 150	 Learning rate: 0.0000	Loss: 13.755033	 Accuracy: 179/213 (84%)
#
# Confusion Matrix:
# [[25 31]
#  [11 14]]
# Accuracy: 0.48148148148148145
# Precision: 0.44642857142857145
# Recall: 0.6944444444444444
# F1-Score: 0.5434782608695653
#
# =========================================================================================
# Train Epoch: 151	 Learning rate: 0.0000	Loss: 13.732849	 Accuracy: 181/213 (85%)
#
# Confusion Matrix:
# [[25 31]
#  [11 14]]
# Accuracy: 0.48148148148148145
# Precision: 0.44642857142857145
# Recall: 0.6944444444444444
# F1-Score: 0.5434782608695653
#
# =========================================================================================
# Train Epoch: 152	 Learning rate: 0.0000	Loss: 13.750810	 Accuracy: 179/213 (84%)
#
# Confusion Matrix:
# [[25 31]
#  [11 14]]
# Accuracy: 0.48148148148148145
# Precision: 0.44642857142857145
# Recall: 0.6944444444444444
# F1-Score: 0.5434782608695653
#
# =========================================================================================
# Train Epoch: 153	 Learning rate: 0.0000	Loss: 13.554442	 Accuracy: 180/213 (85%)
#
# Confusion Matrix:
# [[25 31]
#  [11 14]]
# Accuracy: 0.48148148148148145
# Precision: 0.44642857142857145
# Recall: 0.6944444444444444
# F1-Score: 0.5434782608695653
#
# =========================================================================================
# Train Epoch: 154	 Learning rate: 0.0000	Loss: 13.557929	 Accuracy: 180/213 (85%)
#
# Confusion Matrix:
# [[25 30]
#  [11 15]]
# Accuracy: 0.49382716049382713
# Precision: 0.45454545454545453
# Recall: 0.6944444444444444
# F1-Score: 0.5494505494505494
#
# =========================================================================================
# Train Epoch: 155	 Learning rate: 0.0000	Loss: 13.444684	 Accuracy: 181/213 (85%)
#
# Confusion Matrix:
# [[24 30]
#  [12 15]]
# Accuracy: 0.48148148148148145
# Precision: 0.4444444444444444
# Recall: 0.6666666666666666
# F1-Score: 0.5333333333333333
#
# =========================================================================================
# Train Epoch: 156	 Learning rate: 0.0000	Loss: 13.375249	 Accuracy: 185/213 (87%)
#
# Confusion Matrix:
# [[23 30]
#  [13 15]]
# Accuracy: 0.4691358024691358
# Precision: 0.4339622641509434
# Recall: 0.6388888888888888
# F1-Score: 0.5168539325842696
#
# =========================================================================================
# Train Epoch: 157	 Learning rate: 0.0000	Loss: 13.362870	 Accuracy: 190/213 (89%)
#
# Confusion Matrix:
# [[23 29]
#  [13 16]]
# Accuracy: 0.48148148148148145
# Precision: 0.4423076923076923
# Recall: 0.6388888888888888
# F1-Score: 0.5227272727272726
#
# =========================================================================================
# Train Epoch: 158	 Learning rate: 0.0000	Loss: 13.293305	 Accuracy: 184/213 (86%)
#
# Confusion Matrix:
# [[23 27]
#  [13 18]]
# Accuracy: 0.5061728395061729
# Precision: 0.46
# Recall: 0.6388888888888888
# F1-Score: 0.5348837209302325
#
# =========================================================================================
# Train Epoch: 159	 Learning rate: 0.0000	Loss: 13.346687	 Accuracy: 185/213 (87%)
#
# Confusion Matrix:
# [[23 27]
#  [13 18]]
# Accuracy: 0.5061728395061729
# Precision: 0.46
# Recall: 0.6388888888888888
# F1-Score: 0.5348837209302325
#
# =========================================================================================
# Train Epoch: 160	 Learning rate: 0.0000	Loss: 13.316982	 Accuracy: 187/213 (88%)
#
# Confusion Matrix:
# [[23 27]
#  [13 18]]
# Accuracy: 0.5061728395061729
# Precision: 0.46
# Recall: 0.6388888888888888
# F1-Score: 0.5348837209302325
#
# =========================================================================================
# Train Epoch: 161	 Learning rate: 0.0000	Loss: 13.222890	 Accuracy: 180/213 (85%)
#
# Confusion Matrix:
# [[23 27]
#  [13 18]]
# Accuracy: 0.5061728395061729
# Precision: 0.46
# Recall: 0.6388888888888888
# F1-Score: 0.5348837209302325
#
# =========================================================================================
# Train Epoch: 162	 Learning rate: 0.0000	Loss: 13.198423	 Accuracy: 185/213 (87%)
#
# Confusion Matrix:
# [[21 27]
#  [15 18]]
# Accuracy: 0.48148148148148145
# Precision: 0.4375
# Recall: 0.5833333333333334
# F1-Score: 0.5
#
# =========================================================================================
# Train Epoch: 163	 Learning rate: 0.0000	Loss: 13.045546	 Accuracy: 189/213 (89%)
#
# Confusion Matrix:
# [[19 27]
#  [17 18]]
# Accuracy: 0.4567901234567901
# Precision: 0.41304347826086957
# Recall: 0.5277777777777778
# F1-Score: 0.4634146341463415
#
# =========================================================================================
# Train Epoch: 164	 Learning rate: 0.0000	Loss: 12.834187	 Accuracy: 193/213 (91%)
#
# Confusion Matrix:
# [[19 25]
#  [17 20]]
# Accuracy: 0.48148148148148145
# Precision: 0.4318181818181818
# Recall: 0.5277777777777778
# F1-Score: 0.47500000000000003
#
# =========================================================================================
# Train Epoch: 165	 Learning rate: 0.0000	Loss: 12.762963	 Accuracy: 197/213 (92%)
#
# Confusion Matrix:
# [[19 25]
#  [17 20]]
# Accuracy: 0.48148148148148145
# Precision: 0.4318181818181818
# Recall: 0.5277777777777778
# F1-Score: 0.47500000000000003
#
# =========================================================================================
# Train Epoch: 166	 Learning rate: 0.0000	Loss: 12.891233	 Accuracy: 194/213 (91%)
#
# Confusion Matrix:
# [[19 25]
#  [17 20]]
# Accuracy: 0.48148148148148145
# Precision: 0.4318181818181818
# Recall: 0.5277777777777778
# F1-Score: 0.47500000000000003
#
# =========================================================================================
# Train Epoch: 167	 Learning rate: 0.0000	Loss: 12.781737	 Accuracy: 192/213 (90%)
#
# Confusion Matrix:
# [[19 25]
#  [17 20]]
# Accuracy: 0.48148148148148145
# Precision: 0.4318181818181818
# Recall: 0.5277777777777778
# F1-Score: 0.47500000000000003
#
# =========================================================================================
# Train Epoch: 168	 Learning rate: 0.0000	Loss: 12.844960	 Accuracy: 186/213 (87%)
#
# Confusion Matrix:
# [[19 25]
#  [17 20]]
# Accuracy: 0.48148148148148145
# Precision: 0.4318181818181818
# Recall: 0.5277777777777778
# F1-Score: 0.47500000000000003
#
# =========================================================================================
# Train Epoch: 169	 Learning rate: 0.0000	Loss: 12.725728	 Accuracy: 195/213 (92%)
#
# Confusion Matrix:
# [[19 23]
#  [17 22]]
# Accuracy: 0.5061728395061729
# Precision: 0.4523809523809524
# Recall: 0.5277777777777778
# F1-Score: 0.4871794871794871
#
# =========================================================================================
# Train Epoch: 170	 Learning rate: 0.0000	Loss: 12.674815	 Accuracy: 197/213 (92%)
#
# Confusion Matrix:
# [[19 23]
#  [17 22]]
# Accuracy: 0.5061728395061729
# Precision: 0.4523809523809524
# Recall: 0.5277777777777778
# F1-Score: 0.4871794871794871
#
# =========================================================================================
