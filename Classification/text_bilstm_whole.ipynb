# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F
import torch.optim as optim
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

import numpy as np
# import pandas as pd
import os
import pickle
import random
import itertools

# %%
prefix = os.path.abspath(os.path.join(os.getcwd(), ".."))
text_features = np.load(os.path.join(prefix, 'Features/TextWhole/whole_samples_clf_avg.npz'))['arr_0']
text_targets = np.load(os.path.join(prefix, 'Features/TextWhole/whole_labels_clf_avg.npz'))['arr_0']
text_dep_idxs_tmp = np.where(text_targets == 1)[0]
text_non_idxs = np.where(text_targets == 0)[0]

# %%
class TextBiLSTM(nn.Module):
    def __init__(self, config):
        super(TextBiLSTM, self).__init__()
        self.num_classes = config['num_classes']
        self.learning_rate = config['learning_rate']
        self.dropout = config['dropout']
        self.hidden_dims = config['hidden_dims']
        self.rnn_layers = config['rnn_layers']
        self.embedding_size = config['embedding_size']
        self.bidirectional = config['bidirectional']

        self.build_model()
        self.init_weight()
        
    def init_weight(net):
        for name, param in net.named_parameters():
            if 'ln' not in name:
                if 'bias' in name:
                    nn.init.constant_(param, 0.0)
                elif 'weight' in name:
                    nn.init.xavier_uniform_(param)

    def build_model(self):
        # attention layer
        self.attention_layer = nn.Sequential(
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(inplace=True)
        )
        # self.attention_weights = self.attention_weights.view(self.hidden_dims, 1)

        # 双层lstm
        self.lstm_net = nn.LSTM(self.embedding_size, self.hidden_dims,
                                num_layers=self.rnn_layers, dropout=self.dropout,
                                bidirectional=self.bidirectional)
                
        # FC层
        # self.fc_out = nn.Linear(self.hidden_dims, self.num_classes)
        self.fc_out = nn.Sequential(
            # nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(),
            nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.num_classes),
            # nn.ReLU(),
            nn.Softmax(dim=1),
        )

        self.ln1 = nn.LayerNorm(self.embedding_size)
        self.ln2 = nn.LayerNorm(self.hidden_dims)


    def attention_net_with_w(self, lstm_out, lstm_hidden):
        '''
        :param lstm_out:    [batch_size, len_seq, n_hidden * 2]
        :param lstm_hidden: [batch_size, num_layers * num_directions, n_hidden]
        :return: [batch_size, n_hidden]
        '''
        lstm_tmp_out = torch.chunk(lstm_out, 2, -1)
        # h [batch_size, time_step, hidden_dims]
        h = lstm_tmp_out[0] + lstm_tmp_out[1]
        # h = lstm_out
        # [batch_size, num_layers * num_directions, n_hidden]
        lstm_hidden = torch.sum(lstm_hidden, dim=1)
        # [batch_size, 1, n_hidden]
        lstm_hidden = lstm_hidden.unsqueeze(1)
        # atten_w [batch_size, 1, hidden_dims]
        atten_w = self.attention_layer(lstm_hidden)
        # m [batch_size, time_step, hidden_dims]
        m = nn.Tanh()(h)
        # atten_context [batch_size, 1, time_step]
        atten_context = torch.bmm(atten_w, m.transpose(1, 2))
        # softmax_w [batch_size, 1, time_step]
        softmax_w = F.softmax(atten_context, dim=-1)
        # context [batch_size, 1, hidden_dims]
        context = torch.bmm(softmax_w, h)
        result = context.squeeze(1)
        return result

    def forward(self, x):
        # x : [len_seq, batch_size, embedding_dim]
        x = x.permute(1, 0, 2)
        # x = self.ln1(x)
        output, (final_hidden_state, _) = self.lstm_net(x)
        # output : [batch_size, len_seq, n_hidden * 2]
        output = output.permute(1, 0, 2)
        # final_hidden_state : [batch_size, num_layers * num_directions, n_hidden]
        final_hidden_state = final_hidden_state.permute(1, 0, 2)
        # final_hidden_state = torch.mean(final_hidden_state, dim=0, keepdim=True)
        # atten_out = self.attention_net(output, final_hidden_state)
        atten_out = self.attention_net_with_w(output, final_hidden_state)
        # atten_out = self.ln2(atten_out)
        return self.fc_out(atten_out)

# %%
def save(model, filename):
    save_filename = '{}.pt'.format(filename)
    torch.save(model, save_filename)
    print('Saved as %s' % save_filename)
    
def standard_confusion_matrix(y_test, y_test_pred):
    """
    Make confusion matrix with format:
                  -----------
                  | TP | FP |
                  -----------
                  | FN | TN |
                  -----------
    Parameters
    ----------
    y_true : ndarray - 1D
    y_pred : ndarray - 1D

    Returns
    -------
    ndarray - 2D
    """
    [[tn, fp], [fn, tp]] = confusion_matrix(y_test, y_test_pred)
    return np.array([[tp, fp], [fn, tn]])

def model_performance(y_test, y_test_pred_proba):
    """
    Evaluation metrics for network performance.
    """
    y_test_pred = y_test_pred_proba.data.max(1, keepdim=True)[1]

    # Computing confusion matrix for test dataset
    conf_matrix = standard_confusion_matrix(y_test, y_test_pred)
    print("Confusion Matrix:")
    print(conf_matrix)

    return y_test_pred, conf_matrix

# %%
def train(epoch, train_idxs):
    global lr, train_acc
    model.train()
    batch_idx = 1
    total_loss = 0
    correct = 0
    X_train = text_features[train_idxs]
    Y_train = text_targets[train_idxs]
    for i in range(0, X_train.shape[0], config['batch_size']):
        if i + config['batch_size'] > X_train.shape[0]:
            x, y = X_train[i:], Y_train[i:]
        else:
            x, y = X_train[i:(i + config['batch_size'])], Y_train[i:(
                i + config['batch_size'])]
        if config['cuda']:
            x, y = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad=True).cuda(), Variable(torch.from_numpy(y)).cuda()
        else:
            x, y = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad=True), \
                Variable(torch.from_numpy(y))

        # 将模型的参数梯度设置为0
        optimizer.zero_grad()
        output = model(x)
        pred = output.data.max(1, keepdim=True)[1]
        #print(pred.shape, y.shape)
        correct += pred.eq(y.data.view_as(pred)).cpu().sum()
        loss = criterion(output, y.long())
        # 后向传播调整参数
        loss.backward()
        # 根据梯度更新网络参数
        optimizer.step()
        batch_idx += 1
        # loss.item()能够得到张量中的元素值
        total_loss += loss.item()

    train_acc = correct
    print(
        'Train Epoch: {:2d}\t Learning rate: {:.4f}\tLoss: {:.6f}\t Accuracy: {}/{} ({:.0f}%)\n '
        .format(epoch + 1, config['learning_rate'], total_loss, correct,
                X_train.shape[0], 100. * correct / X_train.shape[0]))

# %%
def evaluate(model, test_idxs, fold, train_idxs):
    model.eval()
    batch_idx = 1
    total_loss = 0
    global max_f1, max_acc, min_mae, X_test_lens, max_prec, max_rec
    pred = np.array([])
    with torch.no_grad():
        if config['cuda']:
            x, y = Variable(torch.from_numpy(text_features[test_idxs]).type(torch.FloatTensor), requires_grad=True).cuda(),\
                Variable(torch.from_numpy(text_targets[test_idxs])).cuda()
        else:
            x, y = Variable(torch.from_numpy(text_features[test_idxs]).type(torch.FloatTensor), requires_grad=True), \
                Variable(torch.from_numpy(text_targets[test_idxs])).type(torch.LongTensor)

        optimizer.zero_grad()
        output = model(x)
        loss = criterion(output, y.long())
        total_loss += loss.item()
        y_test_pred, conf_matrix = model_performance(y, output.cpu())
        accuracy = float(conf_matrix[0][0] + conf_matrix[1][1]) / np.sum(conf_matrix)
        precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
        recall = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[1][0])
        f1_score = 2 * (precision * recall) / (precision + recall)
        print("Accuracy: {}".format(accuracy))
        print("Precision: {}".format(precision))
        print("Recall: {}".format(recall))
        print("F1-Score: {}\n".format(f1_score))
        print('=' * 89)

        if max_f1 <= f1_score and train_acc > len(train_idxs)*0.9 and f1_score > 0.5:
            max_f1 = f1_score
            max_acc = accuracy
            max_rec = recall
            max_prec = precision
            save(model, os.path.join(prefix, 'Model/ClassificationWhole/Text/BiLSTM_{}_{:.2f}_{}'.format(config['hidden_dims'], max_f1, fold)))
            print('*' * 64)
            print('model saved: f1: {}\tacc: {}'.format(max_f1, max_acc))
            print('*' * 64)

    return total_loss

# %%
def get_param_group(model):
    nd_list = []
    param_list = []
    for name, param in model.named_parameters():
        if 'ln' in name:
            nd_list.append(param)
        else:
            param_list.append(param)
    return [{'params': param_list, 'weight_decay': 1e-5}, {'params': nd_list, 'weight_decay': 0}]

# %%
config = {
    'num_classes': 2,
    'dropout': 0.5,
    'rnn_layers': 2,
    'embedding_size': 1024,
    'batch_size': 4,
    'epochs': 150,
    'learning_rate': 1e-5,
    'hidden_dims': 128,
    'bidirectional': True,
    'cuda': False,
}

train_idxs_tmps = [np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_1.npy'), allow_pickle=True),
np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_2.npy'), allow_pickle=True),
np.load(os.path.join(prefix, 'Features/TextWhole/train_idxs_3.npy'), allow_pickle=True)]
fold = 1

# %%
for idx_idx, train_idxs_tmp in enumerate(train_idxs_tmps):
    # if idx_idx != 2:
    #     continue
    test_idxs_tmp = list(set(list(text_dep_idxs_tmp)+list(text_non_idxs)) - set(train_idxs_tmp))
    train_idxs, test_idxs = [], []
    # depression data augmentation
    for idx in train_idxs_tmp:
        if idx in text_dep_idxs_tmp:
            feat = text_features[idx]
            count = 0
            resample_idxs = [0,1,2,3,4,5]
            for i in itertools.permutations(feat, feat.shape[0]):
                if count in resample_idxs:
                    text_features = np.vstack((text_features, np.expand_dims(list(i), 0)))
                    text_targets = np.hstack((text_targets, 1))
                    train_idxs.append(len(text_features)-1)
                count += 1
        else:
            train_idxs.append(idx)

    for idx in test_idxs_tmp:
        if idx in text_dep_idxs_tmp:
            feat = text_features[idx]
            count = 0
            # resample_idxs = random.sample(range(6), 4)
            resample_idxs = [0,1,4,5]
            for i in itertools.permutations(feat, feat.shape[0]):
                if count in resample_idxs:
                    text_features = np.vstack((text_features, np.expand_dims(list(i), 0)))
                    text_targets = np.hstack((text_targets, 1))
                    test_idxs.append(len(text_features)-1)
                count += 1
        else:
            test_idxs.append(idx)

    model = TextBiLSTM(config)

    param_group = get_param_group(model)
    optimizer = optim.AdamW(param_group, lr=config['learning_rate'])
    criterion = nn.CrossEntropyLoss()
    max_f1 = -1
    max_acc = -1
    max_rec = -1
    max_prec = -1
    train_acc = -1

    for ep in range(1, config['epochs']):
        train(ep, train_idxs)
        tloss = evaluate(model, test_idxs, fold, train_idxs)
    fold += 1
# Out:
# Train Epoch:  2	 Learning rate: 0.0000	Loss: 35.231765	 Accuracy: 112/203 (55%)
#
# Confusion Matrix:
# [[38 42]
#  [ 6  1]]
# Accuracy: 0.4482758620689655
# Precision: 0.475
# Recall: 0.8636363636363636
# F1-Score: 0.6129032258064516
#
# =========================================================================================
# Train Epoch:  3	 Learning rate: 0.0000	Loss: 35.306460	 Accuracy: 97/203 (48%)
#
# Confusion Matrix:
# [[40 43]
#  [ 4  0]]
# Accuracy: 0.45977011494252873
# Precision: 0.4819277108433735
# Recall: 0.9090909090909091
# F1-Score: 0.6299212598425197
#
# =========================================================================================
# Train Epoch:  4	 Learning rate: 0.0000	Loss: 35.095755	 Accuracy: 118/203 (58%)
#
# Confusion Matrix:
# [[40 43]
#  [ 4  0]]
# Accuracy: 0.45977011494252873
# Precision: 0.4819277108433735
# Recall: 0.9090909090909091
# F1-Score: 0.6299212598425197
#
# =========================================================================================
# Train Epoch:  5	 Learning rate: 0.0000	Loss: 35.037768	 Accuracy: 116/203 (57%)
#
# Confusion Matrix:
# [[43 43]
#  [ 1  0]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.9772727272727273
# F1-Score: 0.6615384615384615
#
# =========================================================================================
# Train Epoch:  6	 Learning rate: 0.0000	Loss: 35.048473	 Accuracy: 112/203 (55%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch:  7	 Learning rate: 0.0000	Loss: 34.919534	 Accuracy: 116/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch:  8	 Learning rate: 0.0000	Loss: 35.006712	 Accuracy: 114/203 (56%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch:  9	 Learning rate: 0.0000	Loss: 34.773823	 Accuracy: 117/203 (58%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 10	 Learning rate: 0.0000	Loss: 34.644626	 Accuracy: 116/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 11	 Learning rate: 0.0000	Loss: 34.676578	 Accuracy: 113/203 (56%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 12	 Learning rate: 0.0000	Loss: 34.594680	 Accuracy: 115/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 13	 Learning rate: 0.0000	Loss: 34.641609	 Accuracy: 114/203 (56%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 14	 Learning rate: 0.0000	Loss: 34.545007	 Accuracy: 114/203 (56%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 15	 Learning rate: 0.0000	Loss: 34.512273	 Accuracy: 116/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 16	 Learning rate: 0.0000	Loss: 34.225863	 Accuracy: 118/203 (58%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 17	 Learning rate: 0.0000	Loss: 34.182433	 Accuracy: 116/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 18	 Learning rate: 0.0000	Loss: 34.122961	 Accuracy: 116/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 19	 Learning rate: 0.0000	Loss: 34.224422	 Accuracy: 116/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 20	 Learning rate: 0.0000	Loss: 34.150216	 Accuracy: 115/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 21	 Learning rate: 0.0000	Loss: 34.130400	 Accuracy: 114/203 (56%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 22	 Learning rate: 0.0000	Loss: 33.962200	 Accuracy: 119/203 (59%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 23	 Learning rate: 0.0000	Loss: 33.881585	 Accuracy: 116/203 (57%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 24	 Learning rate: 0.0000	Loss: 33.732867	 Accuracy: 117/203 (58%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 25	 Learning rate: 0.0000	Loss: 33.973279	 Accuracy: 118/203 (58%)
#
# Confusion Matrix:
# [[44 43]
#  [ 0  0]]
# Accuracy: 0.5057471264367817
# Precision: 0.5057471264367817
# Recall: 1.0
# F1-Score: 0.6717557251908397
#
# =========================================================================================
# Train Epoch: 26	 Learning rate: 0.0000	Loss: 33.674951	 Accuracy: 117/203 (58%)
#
# Confusion Matrix:
# [[44 42]
#  [ 0  1]]
# Accuracy: 0.5172413793103449
# Precision: 0.5116279069767442
# Recall: 1.0
# F1-Score: 0.676923076923077
#
# =========================================================================================
# Train Epoch: 27	 Learning rate: 0.0000	Loss: 33.720719	 Accuracy: 121/203 (60%)
#
# Confusion Matrix:
# [[44 42]
#  [ 0  1]]
# Accuracy: 0.5172413793103449
# Precision: 0.5116279069767442
# Recall: 1.0
# F1-Score: 0.676923076923077
#
# =========================================================================================
# Train Epoch: 28	 Learning rate: 0.0000	Loss: 33.565968	 Accuracy: 124/203 (61%)
#
# Confusion Matrix:
# [[40 40]
#  [ 4  3]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.9090909090909091
# F1-Score: 0.6451612903225806
#
# =========================================================================================
# Train Epoch: 29	 Learning rate: 0.0000	Loss: 33.576916	 Accuracy: 120/203 (59%)
#
# Confusion Matrix:
# [[39 39]
#  [ 5  4]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.8863636363636364
# F1-Score: 0.639344262295082
#
# =========================================================================================
# Train Epoch: 30	 Learning rate: 0.0000	Loss: 33.487892	 Accuracy: 123/203 (61%)
#
# Confusion Matrix:
# [[36 37]
#  [ 8  6]]
# Accuracy: 0.4827586206896552
# Precision: 0.4931506849315068
# Recall: 0.8181818181818182
# F1-Score: 0.6153846153846154
#
# =========================================================================================
# Train Epoch: 31	 Learning rate: 0.0000	Loss: 33.309818	 Accuracy: 132/203 (65%)
#
# Confusion Matrix:
# [[35 36]
#  [ 9  7]]
# Accuracy: 0.4827586206896552
# Precision: 0.49295774647887325
# Recall: 0.7954545454545454
# F1-Score: 0.6086956521739131
#
# =========================================================================================
# Train Epoch: 32	 Learning rate: 0.0000	Loss: 33.115248	 Accuracy: 128/203 (63%)
#
# Confusion Matrix:
# [[34 35]
#  [10  8]]
# Accuracy: 0.4827586206896552
# Precision: 0.4927536231884058
# Recall: 0.7727272727272727
# F1-Score: 0.6017699115044248
#
# =========================================================================================
# Train Epoch: 33	 Learning rate: 0.0000	Loss: 33.101766	 Accuracy: 130/203 (64%)
#
# Confusion Matrix:
# [[33 34]
#  [11  9]]
# Accuracy: 0.4827586206896552
# Precision: 0.4925373134328358
# Recall: 0.75
# F1-Score: 0.5945945945945946
#
# =========================================================================================
# Train Epoch: 34	 Learning rate: 0.0000	Loss: 33.155470	 Accuracy: 131/203 (65%)
#
# Confusion Matrix:
# [[33 32]
#  [11 11]]
# Accuracy: 0.5057471264367817
# Precision: 0.5076923076923077
# Recall: 0.75
# F1-Score: 0.6055045871559633
#
# =========================================================================================
# Train Epoch: 35	 Learning rate: 0.0000	Loss: 32.963495	 Accuracy: 136/203 (67%)
#
# Confusion Matrix:
# [[28 28]
#  [16 15]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.6363636363636364
# F1-Score: 0.56
#
# =========================================================================================
# Train Epoch: 36	 Learning rate: 0.0000	Loss: 32.896491	 Accuracy: 138/203 (68%)
#
# Confusion Matrix:
# [[26 26]
#  [18 17]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.5909090909090909
# F1-Score: 0.5416666666666667
#
# =========================================================================================
# Train Epoch: 37	 Learning rate: 0.0000	Loss: 32.899130	 Accuracy: 140/203 (69%)
#
# Confusion Matrix:
# [[26 26]
#  [18 17]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.5909090909090909
# F1-Score: 0.5416666666666667
#
# =========================================================================================
# Train Epoch: 38	 Learning rate: 0.0000	Loss: 32.672546	 Accuracy: 144/203 (71%)
#
# Confusion Matrix:
# [[26 26]
#  [18 17]]
# Accuracy: 0.4942528735632184
# Precision: 0.5
# Recall: 0.5909090909090909
# F1-Score: 0.5416666666666667
#
# =========================================================================================
# Train Epoch: 39	 Learning rate: 0.0000	Loss: 32.404154	 Accuracy: 150/203 (74%)
#
# Confusion Matrix:
# [[24 23]
#  [20 20]]
# Accuracy: 0.5057471264367817
# Precision: 0.5106382978723404
# Recall: 0.5454545454545454
# F1-Score: 0.5274725274725275
#
# =========================================================================================
# Train Epoch: 40	 Learning rate: 0.0000	Loss: 32.337239	 Accuracy: 146/203 (72%)
#
# Confusion Matrix:
# [[24 19]
#  [20 24]]
# Accuracy: 0.5517241379310345
# Precision: 0.5581395348837209
# Recall: 0.5454545454545454
# F1-Score: 0.5517241379310344
#
# =========================================================================================
# Train Epoch: 41	 Learning rate: 0.0000	Loss: 32.289353	 Accuracy: 145/203 (71%)
#
# Confusion Matrix:
# [[24 17]
#  [20 26]]
# Accuracy: 0.5747126436781609
# Precision: 0.5853658536585366
# Recall: 0.5454545454545454
# F1-Score: 0.5647058823529411
#
# =========================================================================================
# Train Epoch: 42	 Learning rate: 0.0000	Loss: 32.177546	 Accuracy: 143/203 (70%)
#
# Confusion Matrix:
# [[24 17]
#  [20 26]]
# Accuracy: 0.5747126436781609
# Precision: 0.5853658536585366
# Recall: 0.5454545454545454
# F1-Score: 0.5647058823529411
#
# =========================================================================================
# Train Epoch: 43	 Learning rate: 0.0000	Loss: 32.047155	 Accuracy: 143/203 (70%)
#
# Confusion Matrix:
# [[22 17]
#  [22 26]]
# Accuracy: 0.5517241379310345
# Precision: 0.5641025641025641
# Recall: 0.5
# F1-Score: 0.5301204819277109
#
# =========================================================================================
# Train Epoch: 44	 Learning rate: 0.0000	Loss: 31.921998	 Accuracy: 144/203 (71%)
#
# Confusion Matrix:
# [[22 17]
#  [22 26]]
# Accuracy: 0.5517241379310345
# Precision: 0.5641025641025641
# Recall: 0.5
# F1-Score: 0.5301204819277109
#
# =========================================================================================
# Train Epoch: 45	 Learning rate: 0.0000	Loss: 31.595892	 Accuracy: 151/203 (74%)
#
# Confusion Matrix:
# [[22 17]
#  [22 26]]
# Accuracy: 0.5517241379310345
# Precision: 0.5641025641025641
# Recall: 0.5
# F1-Score: 0.5301204819277109
#
# =========================================================================================
# Train Epoch: 46	 Learning rate: 0.0000	Loss: 31.352511	 Accuracy: 159/203 (78%)
#
# Confusion Matrix:
# [[21 14]
#  [23 29]]
# Accuracy: 0.5747126436781609
# Precision: 0.6
# Recall: 0.4772727272727273
# F1-Score: 0.5316455696202532
#
# =========================================================================================
# Train Epoch: 47	 Learning rate: 0.0000	Loss: 31.326481	 Accuracy: 152/203 (75%)
#
# Confusion Matrix:
# [[22 15]
#  [22 28]]
# Accuracy: 0.5747126436781609
# Precision: 0.5945945945945946
# Recall: 0.5
# F1-Score: 0.5432098765432098
#
# =========================================================================================
# Train Epoch: 48	 Learning rate: 0.0000	Loss: 31.127768	 Accuracy: 152/203 (75%)
#
# Confusion Matrix:
# [[20 13]
#  [24 30]]
# Accuracy: 0.5747126436781609
# Precision: 0.6060606060606061
# Recall: 0.45454545454545453
# F1-Score: 0.5194805194805195
#
# =========================================================================================
# Train Epoch: 49	 Learning rate: 0.0000	Loss: 30.890529	 Accuracy: 156/203 (77%)
#
# Confusion Matrix:
# [[19 13]
#  [25 30]]
# Accuracy: 0.5632183908045977
# Precision: 0.59375
# Recall: 0.4318181818181818
# F1-Score: 0.5
#
# =========================================================================================
# Train Epoch: 50	 Learning rate: 0.0000	Loss: 30.572350	 Accuracy: 155/203 (76%)
#
# Confusion Matrix:
# [[20 13]
#  [24 30]]
# Accuracy: 0.5747126436781609
# Precision: 0.6060606060606061
# Recall: 0.45454545454545453
# F1-Score: 0.5194805194805195
#
# =========================================================================================
# Train Epoch: 51	 Learning rate: 0.0000	Loss: 30.795623	 Accuracy: 148/203 (73%)
#
# Confusion Matrix:
# [[20 13]
#  [24 30]]
# Accuracy: 0.5747126436781609
# Precision: 0.6060606060606061
# Recall: 0.45454545454545453
# F1-Score: 0.5194805194805195
#
# =========================================================================================
# Train Epoch: 52	 Learning rate: 0.0000	Loss: 30.166720	 Accuracy: 166/203 (82%)
#
# Confusion Matrix:
# [[20 13]
#  [24 30]]
# Accuracy: 0.5747126436781609
# Precision: 0.6060606060606061
# Recall: 0.45454545454545453
# F1-Score: 0.5194805194805195
#
# =========================================================================================
# Train Epoch: 53	 Learning rate: 0.0000	Loss: 29.912230	 Accuracy: 159/203 (78%)
#
# Confusion Matrix:
# [[20 13]
#  [24 30]]
# Accuracy: 0.5747126436781609
# Precision: 0.6060606060606061
# Recall: 0.45454545454545453
# F1-Score: 0.5194805194805195
#
# =========================================================================================
# Train Epoch: 54	 Learning rate: 0.0000	Loss: 29.593985	 Accuracy: 163/203 (80%)
#
# Confusion Matrix:
# [[20 13]
#  [24 30]]
# Accuracy: 0.5747126436781609
# Precision: 0.6060606060606061
# Recall: 0.45454545454545453
# F1-Score: 0.5194805194805195
#
# =========================================================================================
# Train Epoch: 55	 Learning rate: 0.0000	Loss: 29.293535	 Accuracy: 167/203 (82%)
#
# Confusion Matrix:
# [[19 13]
#  [25 30]]
# Accuracy: 0.5632183908045977
# Precision: 0.59375
# Recall: 0.4318181818181818
# F1-Score: 0.5
#
# =========================================================================================
# Train Epoch: 56	 Learning rate: 0.0000	Loss: 28.905038	 Accuracy: 170/203 (84%)
#
# Confusion Matrix:
# [[19 12]
#  [25 31]]
# Accuracy: 0.5747126436781609
# Precision: 0.6129032258064516
# Recall: 0.4318181818181818
# F1-Score: 0.5066666666666667
#
# =========================================================================================
# Train Epoch: 57	 Learning rate: 0.0000	Loss: 28.886742	 Accuracy: 163/203 (80%)
#
# Confusion Matrix:
# [[19 12]
#  [25 31]]
# Accuracy: 0.5747126436781609
# Precision: 0.6129032258064516
# Recall: 0.4318181818181818
# F1-Score: 0.5066666666666667
#
# =========================================================================================
# Train Epoch: 58	 Learning rate: 0.0000	Loss: 28.473137	 Accuracy: 169/203 (83%)
#
# Confusion Matrix:
# [[19 12]
#  [25 31]]
# Accuracy: 0.5747126436781609
# Precision: 0.6129032258064516
# Recall: 0.4318181818181818
# F1-Score: 0.5066666666666667
#
# =========================================================================================
# Train Epoch: 59	 Learning rate: 0.0000	Loss: 28.178733	 Accuracy: 169/203 (83%)
#
# Confusion Matrix:
# [[20 12]
#  [24 31]]
# Accuracy: 0.5862068965517241
# Precision: 0.625
# Recall: 0.45454545454545453
# F1-Score: 0.5263157894736842
#
# =========================================================================================
# Train Epoch: 60	 Learning rate: 0.0000	Loss: 28.015283	 Accuracy: 167/203 (82%)
#
# Confusion Matrix:
# [[20 12]
#  [24 31]]
# Accuracy: 0.5862068965517241
# Precision: 0.625
# Recall: 0.45454545454545453
# F1-Score: 0.5263157894736842
#
# =========================================================================================
# Train Epoch: 61	 Learning rate: 0.0000	Loss: 27.568127	 Accuracy: 176/203 (87%)
#
# Confusion Matrix:
# [[18 12]
#  [26 31]]
# Accuracy: 0.5632183908045977
# Precision: 0.6
# Recall: 0.4090909090909091
# F1-Score: 0.4864864864864865
#
# =========================================================================================
# Train Epoch: 62	 Learning rate: 0.0000	Loss: 27.316811	 Accuracy: 177/203 (87%)
#
# Confusion Matrix:
# [[18 12]
#  [26 31]]
# Accuracy: 0.5632183908045977
# Precision: 0.6
# Recall: 0.4090909090909091
# F1-Score: 0.4864864864864865
#
# =========================================================================================
# Train Epoch: 63	 Learning rate: 0.0000	Loss: 26.864342	 Accuracy: 176/203 (87%)
#
# Confusion Matrix:
# [[18 12]
#  [26 31]]
# Accuracy: 0.5632183908045977
# Precision: 0.6
# Recall: 0.4090909090909091
# F1-Score: 0.4864864864864865
#
# =========================================================================================
# Train Epoch: 64	 Learning rate: 0.0000	Loss: 26.162789	 Accuracy: 185/203 (91%)
#
# Confusion Matrix:
# [[17 12]
#  [27 31]]
# Accuracy: 0.5517241379310345
# Precision: 0.5862068965517241
# Recall: 0.38636363636363635
# F1-Score: 0.4657534246575343
#
# =========================================================================================
# Train Epoch: 65	 Learning rate: 0.0000	Loss: 26.379536	 Accuracy: 177/203 (87%)
#
# Confusion Matrix:
# [[17 12]
#  [27 31]]
# Accuracy: 0.5517241379310345
# Precision: 0.5862068965517241
# Recall: 0.38636363636363635
# F1-Score: 0.4657534246575343
#
# =========================================================================================
# Train Epoch: 66	 Learning rate: 0.0000	Loss: 26.089879	 Accuracy: 175/203 (86%)
#
# Confusion Matrix:
# [[18 12]
#  [26 31]]
# Accuracy: 0.5632183908045977
# Precision: 0.6
# Recall: 0.4090909090909091
# F1-Score: 0.4864864864864865
#
# =========================================================================================
# Train Epoch: 67	 Learning rate: 0.0000	Loss: 25.297044	 Accuracy: 181/203 (89%)
#
# Confusion Matrix:
# [[17 12]
#  [27 31]]
# Accuracy: 0.5517241379310345
# Precision: 0.5862068965517241
# Recall: 0.38636363636363635
# F1-Score: 0.4657534246575343
#
# =========================================================================================
# Train Epoch: 68	 Learning rate: 0.0000	Loss: 24.709490	 Accuracy: 187/203 (92%)
#
# Confusion Matrix:
# [[19 12]
#  [25 31]]
# Accuracy: 0.5747126436781609
# Precision: 0.6129032258064516
# Recall: 0.4318181818181818
# F1-Score: 0.5066666666666667
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.51_1.pt
# ****************************************************************
# model saved: f1: 0.5066666666666667	acc: 0.5747126436781609
# ****************************************************************
# Train Epoch: 69	 Learning rate: 0.0000	Loss: 25.240272	 Accuracy: 183/203 (90%)
#
# Confusion Matrix:
# [[16 11]
#  [28 32]]
# Accuracy: 0.5517241379310345
# Precision: 0.5925925925925926
# Recall: 0.36363636363636365
# F1-Score: 0.4507042253521127
#
# =========================================================================================
# Train Epoch: 70	 Learning rate: 0.0000	Loss: 24.426637	 Accuracy: 184/203 (91%)
#
# Confusion Matrix:
# [[15 11]
#  [29 32]]
# Accuracy: 0.5402298850574713
# Precision: 0.5769230769230769
# Recall: 0.3409090909090909
# F1-Score: 0.42857142857142855
#
# =========================================================================================
# Train Epoch: 71	 Learning rate: 0.0000	Loss: 24.271673	 Accuracy: 179/203 (88%)
#
# Confusion Matrix:
# [[16 11]
#  [28 32]]
# Accuracy: 0.5517241379310345
# Precision: 0.5925925925925926
# Recall: 0.36363636363636365
# F1-Score: 0.4507042253521127
#
# =========================================================================================
# Train Epoch: 72	 Learning rate: 0.0000	Loss: 23.833985	 Accuracy: 186/203 (92%)
#
# Confusion Matrix:
# [[16 11]
#  [28 32]]
# Accuracy: 0.5517241379310345
# Precision: 0.5925925925925926
# Recall: 0.36363636363636365
# F1-Score: 0.4507042253521127
#
# =========================================================================================
# Train Epoch: 73	 Learning rate: 0.0000	Loss: 23.442012	 Accuracy: 185/203 (91%)
#
# Confusion Matrix:
# [[17 11]
#  [27 32]]
# Accuracy: 0.5632183908045977
# Precision: 0.6071428571428571
# Recall: 0.38636363636363635
# F1-Score: 0.4722222222222222
#
# =========================================================================================
# Train Epoch: 74	 Learning rate: 0.0000	Loss: 22.745543	 Accuracy: 191/203 (94%)
#
# Confusion Matrix:
# [[16 11]
#  [28 32]]
# Accuracy: 0.5517241379310345
# Precision: 0.5925925925925926
# Recall: 0.36363636363636365
# F1-Score: 0.4507042253521127
#
# =========================================================================================
# Train Epoch: 75	 Learning rate: 0.0000	Loss: 22.617856	 Accuracy: 188/203 (93%)
#
# Confusion Matrix:
# [[19 11]
#  [25 32]]
# Accuracy: 0.5862068965517241
# Precision: 0.6333333333333333
# Recall: 0.4318181818181818
# F1-Score: 0.5135135135135135
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.51_1.pt
# ****************************************************************
# model saved: f1: 0.5135135135135135	acc: 0.5862068965517241
# ****************************************************************
# Train Epoch: 76	 Learning rate: 0.0000	Loss: 22.167515	 Accuracy: 190/203 (94%)
#
# Confusion Matrix:
# [[14 10]
#  [30 33]]
# Accuracy: 0.5402298850574713
# Precision: 0.5833333333333334
# Recall: 0.3181818181818182
# F1-Score: 0.4117647058823529
#
# =========================================================================================
# Train Epoch: 77	 Learning rate: 0.0000	Loss: 22.458767	 Accuracy: 186/203 (92%)
#
# Confusion Matrix:
# [[19 10]
#  [25 33]]
# Accuracy: 0.5977011494252874
# Precision: 0.6551724137931034
# Recall: 0.4318181818181818
# F1-Score: 0.5205479452054794
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.52_1.pt
# ****************************************************************
# model saved: f1: 0.5205479452054794	acc: 0.5977011494252874
# ****************************************************************
# Train Epoch: 78	 Learning rate: 0.0000	Loss: 22.019720	 Accuracy: 191/203 (94%)
#
# Confusion Matrix:
# [[20 10]
#  [24 33]]
# Accuracy: 0.6091954022988506
# Precision: 0.6666666666666666
# Recall: 0.45454545454545453
# F1-Score: 0.5405405405405405
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.54_1.pt
# ****************************************************************
# model saved: f1: 0.5405405405405405	acc: 0.6091954022988506
# ****************************************************************
# Train Epoch: 79	 Learning rate: 0.0000	Loss: 21.378097	 Accuracy: 192/203 (95%)
#
# Confusion Matrix:
# [[22 11]
#  [22 32]]
# Accuracy: 0.6206896551724138
# Precision: 0.6666666666666666
# Recall: 0.5
# F1-Score: 0.5714285714285715
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.57_1.pt
# ****************************************************************
# model saved: f1: 0.5714285714285715	acc: 0.6206896551724138
# ****************************************************************
# Train Epoch: 80	 Learning rate: 0.0000	Loss: 21.280108	 Accuracy: 190/203 (94%)
#
# Confusion Matrix:
# [[19 10]
#  [25 33]]
# Accuracy: 0.5977011494252874
# Precision: 0.6551724137931034
# Recall: 0.4318181818181818
# F1-Score: 0.5205479452054794
#
# =========================================================================================
# Train Epoch: 81	 Learning rate: 0.0000	Loss: 21.266170	 Accuracy: 193/203 (95%)
#
# Confusion Matrix:
# [[18 10]
#  [26 33]]
# Accuracy: 0.5862068965517241
# Precision: 0.6428571428571429
# Recall: 0.4090909090909091
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 82	 Learning rate: 0.0000	Loss: 20.739517	 Accuracy: 194/203 (96%)
#
# Confusion Matrix:
# [[18 10]
#  [26 33]]
# Accuracy: 0.5862068965517241
# Precision: 0.6428571428571429
# Recall: 0.4090909090909091
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 83	 Learning rate: 0.0000	Loss: 20.899121	 Accuracy: 191/203 (94%)
#
# Confusion Matrix:
# [[19 10]
#  [25 33]]
# Accuracy: 0.5977011494252874
# Precision: 0.6551724137931034
# Recall: 0.4318181818181818
# F1-Score: 0.5205479452054794
#
# =========================================================================================
# Train Epoch: 84	 Learning rate: 0.0000	Loss: 20.495747	 Accuracy: 191/203 (94%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.61_1.pt
# ****************************************************************
# model saved: f1: 0.6075949367088607	acc: 0.6436781609195402
# ****************************************************************
# Train Epoch: 85	 Learning rate: 0.0000	Loss: 20.099402	 Accuracy: 195/203 (96%)
#
# Confusion Matrix:
# [[18 10]
#  [26 33]]
# Accuracy: 0.5862068965517241
# Precision: 0.6428571428571429
# Recall: 0.4090909090909091
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 86	 Learning rate: 0.0000	Loss: 20.295856	 Accuracy: 195/203 (96%)
#
# Confusion Matrix:
# [[23 11]
#  [21 32]]
# Accuracy: 0.632183908045977
# Precision: 0.6764705882352942
# Recall: 0.5227272727272727
# F1-Score: 0.5897435897435898
#
# =========================================================================================
# Train Epoch: 87	 Learning rate: 0.0000	Loss: 19.861418	 Accuracy: 196/203 (97%)
#
# Confusion Matrix:
# [[21 10]
#  [23 33]]
# Accuracy: 0.6206896551724138
# Precision: 0.6774193548387096
# Recall: 0.4772727272727273
# F1-Score: 0.5599999999999999
#
# =========================================================================================
# Train Epoch: 88	 Learning rate: 0.0000	Loss: 19.820265	 Accuracy: 195/203 (96%)
#
# Confusion Matrix:
# [[21 10]
#  [23 33]]
# Accuracy: 0.6206896551724138
# Precision: 0.6774193548387096
# Recall: 0.4772727272727273
# F1-Score: 0.5599999999999999
#
# =========================================================================================
# Train Epoch: 89	 Learning rate: 0.0000	Loss: 19.654867	 Accuracy: 194/203 (96%)
#
# Confusion Matrix:
# [[24 10]
#  [20 33]]
# Accuracy: 0.6551724137931034
# Precision: 0.7058823529411765
# Recall: 0.5454545454545454
# F1-Score: 0.6153846153846153
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.62_1.pt
# ****************************************************************
# model saved: f1: 0.6153846153846153	acc: 0.6551724137931034
# ****************************************************************
# Train Epoch: 90	 Learning rate: 0.0000	Loss: 19.385840	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 91	 Learning rate: 0.0000	Loss: 19.346752	 Accuracy: 194/203 (96%)
#
# Confusion Matrix:
# [[23 10]
#  [21 33]]
# Accuracy: 0.6436781609195402
# Precision: 0.696969696969697
# Recall: 0.5227272727272727
# F1-Score: 0.5974025974025974
#
# =========================================================================================
# Train Epoch: 92	 Learning rate: 0.0000	Loss: 18.803243	 Accuracy: 200/203 (99%)
#
# Confusion Matrix:
# [[22 10]
#  [22 33]]
# Accuracy: 0.632183908045977
# Precision: 0.6875
# Recall: 0.5
# F1-Score: 0.5789473684210527
#
# =========================================================================================
# Train Epoch: 93	 Learning rate: 0.0000	Loss: 18.641483	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[20 10]
#  [24 33]]
# Accuracy: 0.6091954022988506
# Precision: 0.6666666666666666
# Recall: 0.45454545454545453
# F1-Score: 0.5405405405405405
#
# =========================================================================================
# Train Epoch: 94	 Learning rate: 0.0000	Loss: 18.753551	 Accuracy: 199/203 (98%)
#
# Confusion Matrix:
# [[22 10]
#  [22 33]]
# Accuracy: 0.632183908045977
# Precision: 0.6875
# Recall: 0.5
# F1-Score: 0.5789473684210527
#
# =========================================================================================
# Train Epoch: 95	 Learning rate: 0.0000	Loss: 18.687106	 Accuracy: 198/203 (98%)
#
# Confusion Matrix:
# [[24 10]
#  [20 33]]
# Accuracy: 0.6551724137931034
# Precision: 0.7058823529411765
# Recall: 0.5454545454545454
# F1-Score: 0.6153846153846153
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.62_1.pt
# ****************************************************************
# model saved: f1: 0.6153846153846153	acc: 0.6551724137931034
# ****************************************************************
# Train Epoch: 96	 Learning rate: 0.0000	Loss: 18.261163	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 97	 Learning rate: 0.0000	Loss: 18.215114	 Accuracy: 200/203 (99%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 98	 Learning rate: 0.0000	Loss: 17.962819	 Accuracy: 199/203 (98%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 99	 Learning rate: 0.0000	Loss: 18.068308	 Accuracy: 199/203 (98%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 100	 Learning rate: 0.0000	Loss: 18.430643	 Accuracy: 197/203 (97%)
#
# Confusion Matrix:
# [[21 10]
#  [23 33]]
# Accuracy: 0.6206896551724138
# Precision: 0.6774193548387096
# Recall: 0.4772727272727273
# F1-Score: 0.5599999999999999
#
# =========================================================================================
# Train Epoch: 101	 Learning rate: 0.0000	Loss: 17.850151	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 102	 Learning rate: 0.0000	Loss: 17.588972	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[26 11]
#  [18 32]]
# Accuracy: 0.6666666666666666
# Precision: 0.7027027027027027
# Recall: 0.5909090909090909
# F1-Score: 0.6419753086419754
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.64_1.pt
# ****************************************************************
# model saved: f1: 0.6419753086419754	acc: 0.6666666666666666
# ****************************************************************
# Train Epoch: 103	 Learning rate: 0.0000	Loss: 17.500416	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[25 11]
#  [19 32]]
# Accuracy: 0.6551724137931034
# Precision: 0.6944444444444444
# Recall: 0.5681818181818182
# F1-Score: 0.625
#
# =========================================================================================
# Train Epoch: 104	 Learning rate: 0.0000	Loss: 17.750474	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[22 11]
#  [22 32]]
# Accuracy: 0.6206896551724138
# Precision: 0.6666666666666666
# Recall: 0.5
# F1-Score: 0.5714285714285715
#
# =========================================================================================
# Train Epoch: 105	 Learning rate: 0.0000	Loss: 17.777601	 Accuracy: 200/203 (99%)
#
# Confusion Matrix:
# [[25 11]
#  [19 32]]
# Accuracy: 0.6551724137931034
# Precision: 0.6944444444444444
# Recall: 0.5681818181818182
# F1-Score: 0.625
#
# =========================================================================================
# Train Epoch: 106	 Learning rate: 0.0000	Loss: 17.397196	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[22 11]
#  [22 32]]
# Accuracy: 0.6206896551724138
# Precision: 0.6666666666666666
# Recall: 0.5
# F1-Score: 0.5714285714285715
#
# =========================================================================================
# Train Epoch: 107	 Learning rate: 0.0000	Loss: 17.446665	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[17  9]
#  [27 34]]
# Accuracy: 0.5862068965517241
# Precision: 0.6538461538461539
# Recall: 0.38636363636363635
# F1-Score: 0.48571428571428565
#
# =========================================================================================
# Train Epoch: 108	 Learning rate: 0.0000	Loss: 17.575769	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[25 11]
#  [19 32]]
# Accuracy: 0.6551724137931034
# Precision: 0.6944444444444444
# Recall: 0.5681818181818182
# F1-Score: 0.625
#
# =========================================================================================
# Train Epoch: 109	 Learning rate: 0.0000	Loss: 17.059053	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 110	 Learning rate: 0.0000	Loss: 17.161308	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[28 12]
#  [16 31]]
# Accuracy: 0.6781609195402298
# Precision: 0.7
# Recall: 0.6363636363636364
# F1-Score: 0.6666666666666666
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.67_1.pt
# ****************************************************************
# model saved: f1: 0.6666666666666666	acc: 0.6781609195402298
# ****************************************************************
# Train Epoch: 111	 Learning rate: 0.0000	Loss: 17.100368	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[22 11]
#  [22 32]]
# Accuracy: 0.6206896551724138
# Precision: 0.6666666666666666
# Recall: 0.5
# F1-Score: 0.5714285714285715
#
# =========================================================================================
# Train Epoch: 112	 Learning rate: 0.0000	Loss: 16.991941	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[17  9]
#  [27 34]]
# Accuracy: 0.5862068965517241
# Precision: 0.6538461538461539
# Recall: 0.38636363636363635
# F1-Score: 0.48571428571428565
#
# =========================================================================================
# Train Epoch: 113	 Learning rate: 0.0000	Loss: 17.153818	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[25 11]
#  [19 32]]
# Accuracy: 0.6551724137931034
# Precision: 0.6944444444444444
# Recall: 0.5681818181818182
# F1-Score: 0.625
#
# =========================================================================================
# Train Epoch: 114	 Learning rate: 0.0000	Loss: 17.114744	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[20 11]
#  [24 32]]
# Accuracy: 0.5977011494252874
# Precision: 0.6451612903225806
# Recall: 0.45454545454545453
# F1-Score: 0.5333333333333333
#
# =========================================================================================
# Train Epoch: 115	 Learning rate: 0.0000	Loss: 16.985738	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[20  9]
#  [24 34]]
# Accuracy: 0.6206896551724138
# Precision: 0.6896551724137931
# Recall: 0.45454545454545453
# F1-Score: 0.547945205479452
#
# =========================================================================================
# Train Epoch: 116	 Learning rate: 0.0000	Loss: 16.821530	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 117	 Learning rate: 0.0000	Loss: 16.884573	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[23 11]
#  [21 32]]
# Accuracy: 0.632183908045977
# Precision: 0.6764705882352942
# Recall: 0.5227272727272727
# F1-Score: 0.5897435897435898
#
# =========================================================================================
# Train Epoch: 118	 Learning rate: 0.0000	Loss: 16.748202	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 119	 Learning rate: 0.0000	Loss: 16.565096	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[28 12]
#  [16 31]]
# Accuracy: 0.6781609195402298
# Precision: 0.7
# Recall: 0.6363636363636364
# F1-Score: 0.6666666666666666
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.67_1.pt
# ****************************************************************
# model saved: f1: 0.6666666666666666	acc: 0.6781609195402298
# ****************************************************************
# Train Epoch: 120	 Learning rate: 0.0000	Loss: 16.551524	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[25 11]
#  [19 32]]
# Accuracy: 0.6551724137931034
# Precision: 0.6944444444444444
# Recall: 0.5681818181818182
# F1-Score: 0.625
#
# =========================================================================================
# Train Epoch: 121	 Learning rate: 0.0000	Loss: 16.744423	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[23 11]
#  [21 32]]
# Accuracy: 0.632183908045977
# Precision: 0.6764705882352942
# Recall: 0.5227272727272727
# F1-Score: 0.5897435897435898
#
# =========================================================================================
# Train Epoch: 122	 Learning rate: 0.0000	Loss: 16.510559	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[26 12]
#  [18 31]]
# Accuracy: 0.6551724137931034
# Precision: 0.6842105263157895
# Recall: 0.5909090909090909
# F1-Score: 0.6341463414634148
#
# =========================================================================================
# Train Epoch: 123	 Learning rate: 0.0000	Loss: 16.720477	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[28 12]
#  [16 31]]
# Accuracy: 0.6781609195402298
# Precision: 0.7
# Recall: 0.6363636363636364
# F1-Score: 0.6666666666666666
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.67_1.pt
# ****************************************************************
# model saved: f1: 0.6666666666666666	acc: 0.6781609195402298
# ****************************************************************
# Train Epoch: 124	 Learning rate: 0.0000	Loss: 16.483150	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[24 11]
#  [20 32]]
# Accuracy: 0.6436781609195402
# Precision: 0.6857142857142857
# Recall: 0.5454545454545454
# F1-Score: 0.6075949367088607
#
# =========================================================================================
# Train Epoch: 125	 Learning rate: 0.0000	Loss: 16.537406	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[28 12]
#  [16 31]]
# Accuracy: 0.6781609195402298
# Precision: 0.7
# Recall: 0.6363636363636364
# F1-Score: 0.6666666666666666
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.67_1.pt
# ****************************************************************
# model saved: f1: 0.6666666666666666	acc: 0.6781609195402298
# ****************************************************************
# Train Epoch: 126	 Learning rate: 0.0000	Loss: 16.445504	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[25 11]
#  [19 32]]
# Accuracy: 0.6551724137931034
# Precision: 0.6944444444444444
# Recall: 0.5681818181818182
# F1-Score: 0.625
#
# =========================================================================================
# Train Epoch: 127	 Learning rate: 0.0000	Loss: 16.373019	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[25 11]
#  [19 32]]
# Accuracy: 0.6551724137931034
# Precision: 0.6944444444444444
# Recall: 0.5681818181818182
# F1-Score: 0.625
#
# =========================================================================================
# Train Epoch: 128	 Learning rate: 0.0000	Loss: 16.479523	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[23 10]
#  [21 33]]
# Accuracy: 0.6436781609195402
# Precision: 0.696969696969697
# Recall: 0.5227272727272727
# F1-Score: 0.5974025974025974
#
# =========================================================================================
# Train Epoch: 129	 Learning rate: 0.0000	Loss: 16.517011	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[23 10]
#  [21 33]]
# Accuracy: 0.6436781609195402
# Precision: 0.696969696969697
# Recall: 0.5227272727272727
# F1-Score: 0.5974025974025974
#
# =========================================================================================
# Train Epoch: 130	 Learning rate: 0.0000	Loss: 16.526557	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[23 10]
#  [21 33]]
# Accuracy: 0.6436781609195402
# Precision: 0.696969696969697
# Recall: 0.5227272727272727
# F1-Score: 0.5974025974025974
#
# =========================================================================================
# Train Epoch: 131	 Learning rate: 0.0000	Loss: 16.412610	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[26 11]
#  [18 32]]
# Accuracy: 0.6666666666666666
# Precision: 0.7027027027027027
# Recall: 0.5909090909090909
# F1-Score: 0.6419753086419754
#
# =========================================================================================
# Train Epoch: 132	 Learning rate: 0.0000	Loss: 16.295609	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[29 13]
#  [15 30]]
# Accuracy: 0.6781609195402298
# Precision: 0.6904761904761905
# Recall: 0.6590909090909091
# F1-Score: 0.6744186046511628
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.67_1.pt
# ****************************************************************
# model saved: f1: 0.6744186046511628	acc: 0.6781609195402298
# ****************************************************************
# Train Epoch: 133	 Learning rate: 0.0000	Loss: 16.625327	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[27 12]
#  [17 31]]
# Accuracy: 0.6666666666666666
# Precision: 0.6923076923076923
# Recall: 0.6136363636363636
# F1-Score: 0.6506024096385543
#
# =========================================================================================
# Train Epoch: 134	 Learning rate: 0.0000	Loss: 16.523971	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[28 13]
#  [16 30]]
# Accuracy: 0.6666666666666666
# Precision: 0.6829268292682927
# Recall: 0.6363636363636364
# F1-Score: 0.6588235294117647
#
# =========================================================================================
# Train Epoch: 135	 Learning rate: 0.0000	Loss: 16.178032	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[25 10]
#  [19 33]]
# Accuracy: 0.6666666666666666
# Precision: 0.7142857142857143
# Recall: 0.5681818181818182
# F1-Score: 0.6329113924050633
#
# =========================================================================================
# Train Epoch: 136	 Learning rate: 0.0000	Loss: 16.209287	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[28 13]
#  [16 30]]
# Accuracy: 0.6666666666666666
# Precision: 0.6829268292682927
# Recall: 0.6363636363636364
# F1-Score: 0.6588235294117647
#
# =========================================================================================
# Train Epoch: 137	 Learning rate: 0.0000	Loss: 16.276329	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[14  9]
#  [30 34]]
# Accuracy: 0.5517241379310345
# Precision: 0.6086956521739131
# Recall: 0.3181818181818182
# F1-Score: 0.41791044776119407
#
# ...
# Train Epoch: 99	 Learning rate: 0.0000	Loss: 18.235948	 Accuracy: 198/203 (98%)
#
# Confusion Matrix:
# [[14  3]
#  [30 40]]
# Accuracy: 0.6206896551724138
# Precision: 0.8235294117647058
# Recall: 0.3181818181818182
# F1-Score: 0.45901639344262296
#
# =========================================================================================
# Train Epoch: 100	 Learning rate: 0.0000	Loss: 17.978322	 Accuracy: 198/203 (98%)
#
# Confusion Matrix:
# [[16  5]
#  [28 38]]
# Accuracy: 0.6206896551724138
# Precision: 0.7619047619047619
# Recall: 0.36363636363636365
# F1-Score: 0.4923076923076923
#
# =========================================================================================
# Train Epoch: 101	 Learning rate: 0.0000	Loss: 18.195633	 Accuracy: 197/203 (97%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.50_3.pt
# ****************************************************************
# model saved: f1: 0.5000000000000001	acc: 0.632183908045977
# ****************************************************************
# Train Epoch: 102	 Learning rate: 0.0000	Loss: 17.463782	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.50_3.pt
# ****************************************************************
# model saved: f1: 0.5000000000000001	acc: 0.632183908045977
# ****************************************************************
# Train Epoch: 103	 Learning rate: 0.0000	Loss: 17.858921	 Accuracy: 199/203 (98%)
#
# Confusion Matrix:
# [[14  4]
#  [30 39]]
# Accuracy: 0.6091954022988506
# Precision: 0.7777777777777778
# Recall: 0.3181818181818182
# F1-Score: 0.45161290322580644
#
# =========================================================================================
# Train Epoch: 104	 Learning rate: 0.0000	Loss: 17.253575	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.50_3.pt
# ****************************************************************
# model saved: f1: 0.5000000000000001	acc: 0.632183908045977
# ****************************************************************
# Train Epoch: 105	 Learning rate: 0.0000	Loss: 17.473258	 Accuracy: 200/203 (99%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.50_3.pt
# ****************************************************************
# model saved: f1: 0.5000000000000001	acc: 0.632183908045977
# ****************************************************************
# Train Epoch: 106	 Learning rate: 0.0000	Loss: 16.908728	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[16  3]
#  [28 40]]
# Accuracy: 0.6436781609195402
# Precision: 0.8421052631578947
# Recall: 0.36363636363636365
# F1-Score: 0.5079365079365079
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.51_3.pt
# ****************************************************************
# model saved: f1: 0.5079365079365079	acc: 0.6436781609195402
# ****************************************************************
# Train Epoch: 107	 Learning rate: 0.0000	Loss: 17.087977	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[14  3]
#  [30 40]]
# Accuracy: 0.6206896551724138
# Precision: 0.8235294117647058
# Recall: 0.3181818181818182
# F1-Score: 0.45901639344262296
#
# =========================================================================================
# Train Epoch: 108	 Learning rate: 0.0000	Loss: 17.341716	 Accuracy: 199/203 (98%)
#
# Confusion Matrix:
# [[15  4]
#  [29 39]]
# Accuracy: 0.6206896551724138
# Precision: 0.7894736842105263
# Recall: 0.3409090909090909
# F1-Score: 0.4761904761904762
#
# =========================================================================================
# Train Epoch: 109	 Learning rate: 0.0000	Loss: 17.045461	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 110	 Learning rate: 0.0000	Loss: 16.966848	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[14  3]
#  [30 40]]
# Accuracy: 0.6206896551724138
# Precision: 0.8235294117647058
# Recall: 0.3181818181818182
# F1-Score: 0.45901639344262296
#
# =========================================================================================
# Train Epoch: 111	 Learning rate: 0.0000	Loss: 16.811435	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[15  4]
#  [29 39]]
# Accuracy: 0.6206896551724138
# Precision: 0.7894736842105263
# Recall: 0.3409090909090909
# F1-Score: 0.4761904761904762
#
# =========================================================================================
# Train Epoch: 112	 Learning rate: 0.0000	Loss: 16.931350	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[15  3]
#  [29 40]]
# Accuracy: 0.632183908045977
# Precision: 0.8333333333333334
# Recall: 0.3409090909090909
# F1-Score: 0.4838709677419354
#
# =========================================================================================
# Train Epoch: 113	 Learning rate: 0.0000	Loss: 16.777520	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[15  4]
#  [29 39]]
# Accuracy: 0.6206896551724138
# Precision: 0.7894736842105263
# Recall: 0.3409090909090909
# F1-Score: 0.4761904761904762
#
# =========================================================================================
# Train Epoch: 114	 Learning rate: 0.0000	Loss: 16.886232	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[18  4]
#  [26 39]]
# Accuracy: 0.6551724137931034
# Precision: 0.8181818181818182
# Recall: 0.4090909090909091
# F1-Score: 0.5454545454545455
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.55_3.pt
# ****************************************************************
# model saved: f1: 0.5454545454545455	acc: 0.6551724137931034
# ****************************************************************
# Train Epoch: 115	 Learning rate: 0.0000	Loss: 16.840753	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[17  4]
#  [27 39]]
# Accuracy: 0.6436781609195402
# Precision: 0.8095238095238095
# Recall: 0.38636363636363635
# F1-Score: 0.523076923076923
#
# =========================================================================================
# Train Epoch: 116	 Learning rate: 0.0000	Loss: 16.687545	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 117	 Learning rate: 0.0000	Loss: 16.885208	 Accuracy: 200/203 (99%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 118	 Learning rate: 0.0000	Loss: 16.406786	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 119	 Learning rate: 0.0000	Loss: 16.727091	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[15  3]
#  [29 40]]
# Accuracy: 0.632183908045977
# Precision: 0.8333333333333334
# Recall: 0.3409090909090909
# F1-Score: 0.4838709677419354
#
# =========================================================================================
# Train Epoch: 120	 Learning rate: 0.0000	Loss: 16.559634	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 121	 Learning rate: 0.0000	Loss: 16.711633	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 122	 Learning rate: 0.0000	Loss: 16.835539	 Accuracy: 201/203 (99%)
#
# Confusion Matrix:
# [[19  5]
#  [25 38]]
# Accuracy: 0.6551724137931034
# Precision: 0.7916666666666666
# Recall: 0.4318181818181818
# F1-Score: 0.5588235294117647
#
# =========================================================================================
# Saved as c:\Users\meena\nikk\sem 7\EE798R\Project\Paper 1\github\Multimodal_Depression_Detection\Model/ClassificationWhole/Text/BiLSTM_128_0.56_3.pt
# ****************************************************************
# model saved: f1: 0.5588235294117647	acc: 0.6551724137931034
# ****************************************************************
# Train Epoch: 123	 Learning rate: 0.0000	Loss: 16.514335	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 124	 Learning rate: 0.0000	Loss: 16.468016	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 125	 Learning rate: 0.0000	Loss: 16.643898	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 126	 Learning rate: 0.0000	Loss: 16.337492	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[18  4]
#  [26 39]]
# Accuracy: 0.6551724137931034
# Precision: 0.8181818181818182
# Recall: 0.4090909090909091
# F1-Score: 0.5454545454545455
#
# =========================================================================================
# Train Epoch: 127	 Learning rate: 0.0000	Loss: 16.500279	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 128	 Learning rate: 0.0000	Loss: 16.655049	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 129	 Learning rate: 0.0000	Loss: 16.361343	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[15  3]
#  [29 40]]
# Accuracy: 0.632183908045977
# Precision: 0.8333333333333334
# Recall: 0.3409090909090909
# F1-Score: 0.4838709677419354
#
# =========================================================================================
# Train Epoch: 130	 Learning rate: 0.0000	Loss: 16.238552	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 131	 Learning rate: 0.0000	Loss: 16.370726	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 132	 Learning rate: 0.0000	Loss: 16.181406	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 133	 Learning rate: 0.0000	Loss: 16.285501	 Accuracy: 203/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# Train Epoch: 134	 Learning rate: 0.0000	Loss: 16.312793	 Accuracy: 202/203 (100%)
#
# Confusion Matrix:
# [[16  4]
#  [28 39]]
# Accuracy: 0.632183908045977
# Precision: 0.8
# Recall: 0.36363636363636365
# F1-Score: 0.5000000000000001
#
# =========================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 48
#      45 train_acc = -1
#      47 for ep in range(1, config['epochs']):
# ---> 48     train(ep, train_idxs)
#      49     tloss = evaluate(model, test_idxs, fold, train_idxs)
#      50 fold += 1
#
# Cell In[32], line 29, in train(epoch, train_idxs)
#      27 loss = criterion(output, y.long())
#      28 # 后向传播调整参数
# ---> 29 loss.backward()
#      30 # 根据梯度更新网络参数
#      31 optimizer.step()
#
# File c:\Users\meena\anaconda3\Lib\site-packages\torch\_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File c:\Users\meena\anaconda3\Lib\site-packages\torch\autograd\__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File c:\Users\meena\anaconda3\Lib\site-packages\torch\autograd\graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# KeyboardInterrupt:
